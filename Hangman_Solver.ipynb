# %% [markdown]
# <a href="https://colab.research.google.com/github/tushar2411/Hangman_Solver_TK/blob/main/Hangman_Solver.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Trexquant Interview Project (The Hangman Game)
#
# * Copyright Trexquant Investment LP. All Rights Reserved.
# * Redistribution of this question without written consent from Trexquant is prohibited

# %% [markdown]
# ## Instruction:
# For this coding test, your mission is to write an algorithm that plays the game of Hangman through our API server.
#
# When a user plays Hangman, the server first selects a secret word at random from a list. The server then returns a row of underscores (space separated)—one for each letter in the secret word—and asks the user to guess a letter. If the user guesses a letter that is in the word, the word is redisplayed with all instances of that letter shown in the correct positions, along with any letters correctly guessed on previous turns. If the letter does not appear in the word, the user is charged with an incorrect guess. The user keeps guessing letters until either (1) the user has correctly guessed all the letters in the word
# or (2) the user has made six incorrect guesses.
#
# You are required to write a "guess" function that takes current word (with underscores) as input and returns a guess letter. You will use the API codes below to play 1,000 Hangman games. You have the opportunity to practice before you want to start recording your game results.
#
# Your algorithm is permitted to use a training set of approximately 250,000 dictionary words. Your algorithm will be tested on an entirely disjoint set of 250,000 dictionary words. Please note that this means the words that you will ultimately be tested on do NOT appear in the dictionary that you are given. You are not permitted to use any dictionary other than the training dictionary we provided. This requirement will be strictly enforced by code review.
#
# You are provided with a basic, working algorithm. This algorithm will match the provided masked string (e.g. a _ _ l e) to all possible words in the dictionary, tabulate the frequency of letters appearing in these possible words, and then guess the letter with the highest frequency of appearence that has not already been guessed. If there are no remaining words that match then it will default back to the character frequency distribution of the entire dictionary.
#
# This benchmark strategy is successful approximately 18% of the time. Your task is to design an algorithm that significantly outperforms this benchmark.

# %%
import json
import requests
import random
import string
import secrets
import time
import re
import collections
try:
    from urllib.parse import parse_qs, urlencode, urlparse
except ImportError:
    from urlparse import parse_qs, urlparse
    from urllib import urlencode

# %%
def getNGrams(words,n):
    ngrams = {}
    for word in words:
        if len(word) <n:
            continue
        for i in range(len(word)-n+1):
            ngram = word[i:i+n]
            if ngram not in ngrams:
                ngrams[ngram] = 1
            else:
                ngrams[ngram]+=1
    return ngrams

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
HANGMAN_URL = "https://www.trexsim.com/trexsim/hangman"

class HangmanAPI(object):
    def __init__(self, access_token=None, session=None, timeout=None):
        self.access_token = access_token
        self.session = session or requests.Session()
        self.timeout = timeout
        self.guessed_letters = []
        self.verbose = False
        dictionary_file_location="/content/drive/MyDrive/words_250000_train.txt"
        text_file = open(dictionary_file_location,"r")
        words = text_file.read().splitlines()
        text_file.close()
        self.ngrams=[getNGrams(words,i) for i in range(1,6)]

    def ngramprob(self,word,letter ):
        denominator=0
        underscroll_location=word.find("_")
        for l in string.ascii_lowercase:            
            try:
                denominator+=self.ngrams[len(word)-1][word[:underscroll_location]+l+word[underscroll_location+1:]]
            except:
                pass
        return self.ngrams[len(word)-1][word[:underscroll_location]+letter+word[underscroll_location+1:]]/denominator

        
    def guess(self, word): # word input example: "_ p p _ e "
        ###############################################
        # Replace with your own "guess" function here #
        ###############################################

        # clean the word so that we strip away the space characters
        # replace "_" with "." as "." indicates any character in regular expressions
        # clean_word = word[::2].replace("_",".")
        # guessed=list(set(word)-set("_"))
        word=word[::2]
        available = list(set(string.ascii_lowercase) - set(self.guessed_letters))
        probs=[]
        contributions=[0,0,0,0,0,0]
        for char in available:
            char_prob=0
            for i in range(len(word)):
                if word[i]!="_":
                    continue
                # find the longest continious string without any "_"
                # 2gram
                try: # a _
                    if word[i-1]!="_":
                        contributions[1]+=self.ngramprob(word[i-1:i+1],char)
                        char_prob+=self.ngramprob(word[i-1:i+1],char)
                except:
                    pass
                try: # _ a
                    if word[i+1]!="_":
                        contributions[1]+=self.ngramprob(word[i:i+2],char)
                        char_prob+=self.ngramprob(word[i:i+2],char)
                except:
                    pass
                # 3gram
                try: # a b _
                    if word[i-1]!="_" and word[i-2]!="_":
                        contributions[2]+=self.ngramprob(word[i-2:i+1],char)
                        char_prob+=self.ngramprob(word[i-2:i+1],char)
                except:
                    pass
                try:
                    # a _ b
                    if word[i+1]!="_" and word[i-1]!="_":
                        contributions[2]+=self.ngramprob(word[i-1:i+2],char)
                        char_prob+=self.ngramprob(word[i-1:i+2],char)
                except:
                    pass
                try: # a b _
                    if word[i+1]!="_" and word[i+2]!="_":
                        contributions[2]+=self.ngramprob(word[i:i+3],char)
                        char_prob+=self.ngramprob(word[i:i+3],char)
                except:
                    pass
                # 4gram
                try: # a b c _
                    if word[i-1]!="_" and word[i-2]!="_" and word[i-3]!="_":
                        contributions[3]+=self.ngramprob(word[i-3:i+1],char)
                        char_prob+=self.ngramprob(word[i-3:i+1],char)
                except:
                    pass
                try: # a b _ c
                    if word[i+1]!="_" and word[i-1]!="_" and word[i-2]!="_":
                        contributions[3]+=self.ngramprob(word[i-2:i+2],char)
                        char_prob+=self.ngramprob(word[i-2:i+2],char)
                except:
                    pass
                try: # a _ b c
                    if word[i+1]!="_" and word[i+2]!="_" and word[i-1]!="_":
                        contributions[3]+=self.ngramprob(word[i-1:i+3],char)
                        char_prob+=self.ngramprob(word[i-1:i+3],char)
                except:
                    pass
                try:  # _ a b c
                    if word[i+1]!="_" and word[i+2]!="_" and word[i+3]!="_":
                        contributions[3]+=self.ngramprob(word[i:i+4],char)
                        char_prob+=self.ngramprob(word[i:i+4],char) 
                except:
                    pass
                # 5 gram
                try: # a b c d _
                    if word[i-1]!="_" and word[i-2]!="_" and word[i-3]!="_" and word[i-4]!="_" :
                        contributions[4]+=self.ngramprob(word[i-4:i+1],char)
                        char_prob+=self.ngramprob(word[i-4:i+1],char)
                except:
                    pass
                try: # a b c _ d
                    if word[i+1]!="_" and word[i-1]!="_" and word[i-2]!="_" and word[i-3]!="_" :
                        contributions[4]+=self.ngramprob(word[i-3:i+2],char)
                        char_prob+=self.ngramprob(word[i-3:i+2],char)
                except:
                    pass
                try: # a b _ c d
                    if word[i+1]!="_" and word[i+2]!="_" and word[i-1]!="_" and word[i-2]!="_" :
                        contributions[4]+=self.ngramprob(word[i-2:i+3],char)
                        char_prob+=self.ngramprob(word[i-2:i+3],char)
                except:
                    pass
                try: # a _ b c d
                    if word[i+1]!="_" and word[i+2]!="_" and word[i+3]!="_" and word[i-1]!="_" :
                        contributions[4]+=self.ngramprob(word[i-1:i+4],char)
                        char_prob+=self.ngramprob(word[i-1:i+4],char)
                except:
                    pass
                try: # _ a b c d
                    if word[i+1]!="_" and word[i+2]!="_" and word[i+3]!="_" and word[i+4]!="_" :
                        contributions[4]+=self.ngramprob(word[i:i+5],char)
                        char_prob+=self.ngramprob(word[i:i+5],char)
                except:
                    pass
                # 6 gram
                try: # a b c d e _
                    if word[i-1]!="_" and word[i-2]!="_" and word[i-3]!="_" and word[i-4]!="_" and word[i-5]!="_" :
                        contributions[5]+=self.ngramprob(word[i-5:i+1],char)
                        char_prob+=self.ngramprob(word[i-5:i+1],char)
                except:
                    pass
                try: # a b c d _ e
                    if word[i+1]!="_" and word[i-1]!="_" and word[i-2]!="_" and word[i-3]!="_" and word[i-4]!="_" :
                        contributions[5]+=self.ngramprob(word[i-4:i+2],char)
                        char_prob+=self.ngramprob(word[i-4:i+2],char)
                except:
                    pass
                try: # a b c _ d e
                    if word[i+1]!="_" and word[i+2]!="_" and word[i-1]!="_" and word[i-2]!="_" and word[i-3]!="_" :
                        contributions[5]+=self.ngramprob(word[i-3:i+3],char)
                        char_prob+=self.ngramprob(word[i-3:i+3],char)
                except:
                    pass
                try: # a b _ c d e
                    if word[i+1]!="_" and word[i+2]!="_" and word[i+3]!="_" and word[i-1]!="_" and word[i-2]!="_" :
                        contributions[5]+=self.ngramprob(word[i-2:i+4],char)
                        char_prob+=self.ngramprob(word[i-2:i+4],char)
                except:
                    pass
                try: # a _ b c d e
                    if word[i+1]!="_" and word[i+2]!="_" and word[i+3]!="_" and word[i+4]!="_" and word[i-1]!="_" :
                        contributions[5]+=self.ngramprob(word[i-1:i+5],char)
                        char_prob+=self.ngramprob(word[i-1:i+5],char)
                except:
                    pass
                try: # _ a b c d e
                    if word[i+1]!="_" and word[i+2]!="_" and word[i+3]!="_" and word[i+4]!="_" and word[i+5]!="_" :
                        contributions[5]+=self.ngramprob(word[i:i+6],char)
                        char_prob+=self.ngramprob(word[i:i+6],char)
                except:
                    pass

                # 1gram
                char_prob+=self.ngramprob(word[i:i+1],char)
                contributions[0]+=self.ngramprob(word[i:i+1],char)
            probs.append(char_prob)
        # create sorted dictionary of probabilities
        probs_dict=dict(zip(available,probs))
        probs_sorted=sorted(probs_dict.items(), key=lambda x: x[1], reverse=True)
        if self.verbose:
            # iterate on probs_sorted
            for i in probs_sorted:
                print(i[0],round(i[1],2),end=", ")
            print()
            print("contributions:",contributions)
        return available[probs.index(max(probs))]
            
    ##########################################################
    # You'll likely not need to modify any of the code below #
    ##########################################################
    
    def build_dictionary(self, dictionary_file_location):
        text_file = open(dictionary_file_location,"r")
        full_dictionary = text_file.read().splitlines()
        text_file.close()
        return full_dictionary
                
    def start_game(self, practice=True, verbose=True):
        self.verbose = verbose
        # reset guessed letters to empty set and current plausible dictionary to the full dictionary
        self.guessed_letters = []
        # self.current_dictionary = self.full_dictionary
                         
        response = self.request("/new_game", {"practice":practice})
        if response.get('status')=="approved":
            game_id = response.get('game_id')
            word = response.get('word')
            tries_remains = response.get('tries_remains')
            if verbose:
                print("Successfully start a new game! Game ID: {0}. # of tries remaining: {1}. Word: {2}.".format(game_id, tries_remains, word))
            while tries_remains>0:
                # get guessed letter from user code
                guess_letter = self.guess(word)
                    
                # append guessed letter to guessed letters field in hangman object
                self.guessed_letters.append(guess_letter)
                if verbose:
                    print("Guessing letter: {0}".format(guess_letter))
                    
                try:    
                    res = self.request("/guess_letter", {"request":"guess_letter", "game_id":game_id, "letter":guess_letter})
                except HangmanAPIError:
                    print('HangmanAPIError exception caught on request.')
                    continue
                except Exception as e:
                    print('Other exception caught on request.')
                    raise e
               
                if verbose:
                    print("Sever response: {0}".format(res))
                status = res.get('status')
                tries_remains = res.get('tries_remains')
                if status=="success":
                    if verbose:
                        print("Successfully finished game: {0}".format(game_id))
                    return True
                elif status=="failed":
                    reason = res.get('reason', '# of tries exceeded!')
                    if verbose:
                        print("Failed game: {0}. Because of: {1}".format(game_id, reason))
                    return False
                elif status=="ongoing":
                    word = res.get('word')
        else:
            if verbose:
                print("Failed to start a new game")
        return status=="success"
        
    def my_status(self):
        return self.request("/my_status", {})
    def offline(self,wordtobeguessed,verbose=True):
        self.verbose=verbose
        self.guessed_letters=[]
        tries_remains=6
        word = "_ " * len(wordtobeguessed)
        assert len(word) == len(wordtobeguessed) *2
        while tries_remains>0:
                # get guessed letter from user code
            guess_letter = self.guess(word)
            flag=False
            for index in range(len(wordtobeguessed)):
                if wordtobeguessed[index]==guess_letter:
                    word=word[:2*index]+guess_letter+word[2*index+1:]
                    flag=True
            if flag==False:
                tries_remains-=1
                print("Wrong guess, you have",tries_remains,"tries left")
            if "_" not in word:
                print("You won!")
                break
            # append guessed letter to guessed letters field in hangman object
            self.guessed_letters.append(guess_letter)
            # time.sleep(0.5)
            print("Guessed letter: {0}".format(guess_letter))
            print("Current word: {0}".format(word))
            
            # tries_remains -=1
    def request(
            self, path, args=None, post_args=None, method=None):
        if args is None:
            args = dict()
        if post_args is not None:
            method = "POST"

        # Add `access_token` to post_args or args if it has not already been
        # included.
        if self.access_token:
            # If post_args exists, we assume that args either does not exists
            # or it does not need `access_token`.
            if post_args and "access_token" not in post_args:
                post_args["access_token"] = self.access_token
            elif "access_token" not in args:
                args["access_token"] = self.access_token

        num_retry, time_sleep = 5, 2                                                                                        
        for it in range(num_retry):                                                                                         
            try:                                                                                                            
                response = self.session.request(                                                                            
                    method or "GET",                                                                                        
                    HANGMAN_URL + path,                                                                                     
                    timeout=self.timeout,                                                                                   
                    params=args,                                                                                            
                    data=post_args                                                                                          
                )                                                                                                           
                break                                                                                                       
            except requests.HTTPError as e:                                                                                 
                response = json.loads(e.read())                                                                             
                raise HangmanAPIError(response)                                                                             
            except requests.exceptions.SSLError as e:                                                                       
                if it + 1 == num_retry:                                                                                     
                    raise                                                                                                   
                time.sleep(time_sleep)  

        headers = response.headers
        if 'json' in headers['content-type']:
            result = response.json()
        elif "access_token" in parse_qs(response.text):
            query_str = parse_qs(response.text)
            if "access_token" in query_str:
                result = {"access_token": query_str["access_token"][0]}
                if "expires" in query_str:
                    result["expires"] = query_str["expires"][0]
            else:
                raise HangmanAPIError(response.json())
        else:
            raise HangmanAPIError('Maintype was not text, or querystring')

        if result and isinstance(result, dict) and result.get("error"):
            raise HangmanAPIError(result)
        return result
    
class HangmanAPIError(Exception):
    def __init__(self, result):
        self.result = result
        self.code = None
        try:
            self.type = result["error_code"]
        except (KeyError, TypeError):
            self.type = ""

        try:
            self.message = result["error_description"]
        except (KeyError, TypeError):
            try:
                self.message = result["error"]["message"]
                self.code = result["error"].get("code")
                if not self.type:
                    self.type = result["error"].get("type", "")
            except (KeyError, TypeError):
                try:
                    self.message = result["error_msg"]
                except (KeyError, TypeError):
                    self.message = result

        Exception.__init__(self, self.message)

# %% [markdown]
# # API Usage Examples

# %% [markdown]
# ## To start a new game:
# 1. Make sure you have implemented your own "guess" method.
# 2. Use the access_token that we sent you to create your HangmanAPI object.
# 3. Start a game by calling "start_game" method.
# 4. If you wish to test your function without being recorded, set "practice" parameter to 1.
# 5. Note: You have a rate limit of 20 new games per minute. DO NOT start more than 20 new games within one minute.

# %%
api = HangmanAPI(access_token="65e16e6a1b38a2ae58266b363c9e75", timeout=2000)

# %%
api.offline("cancelled")
# Out:
# e 0.99, i 0.78, a 0.76, n 0.64, o 0.64, r 0.63, s 0.63, t 0.58, l 0.52, c 0.38, u 0.33, d 0.32, p 0.28, m 0.26, h 0.25, g 0.22, y 0.17, b 0.17, f 0.11, v 0.09, k 0.08, w 0.08, z 0.04, x 0.03, q 0.02, j 0.02,
# contributions: [9.000000000000002, 0, 0, 0, 0, 0]
# Guessed letter: e
# Current word: _ _ _ _ e _ _ e _
# r 1.1, n 0.91, s 0.88, t 0.79, l 0.74, a 0.72, i 0.71, d 0.6, o 0.54, c 0.45, m 0.38, p 0.36, h 0.31, u 0.3, g 0.26, b 0.21, v 0.19, y 0.16, f 0.14, k 0.11, w 0.1, z 0.06, x 0.05, j 0.02, q 0.02,
# contributions: [6.229924423907611, 3.8976370999817807, 0, 0, 0, 0]
# Wrong guess, you have 5 tries left
# Guessed letter: r
# Current word: _ _ _ _ e _ _ e _
# n 0.91, s 0.88, t 0.79, l 0.74, a 0.72, i 0.71, d 0.6, o 0.54, c 0.45, m 0.38, p 0.36, h 0.31, u 0.3, g 0.26, b 0.21, v 0.19, y 0.16, f 0.14, k 0.11, w 0.1, z 0.06, x 0.05, j 0.02, q 0.02,
# contributions: [5.738291071026841, 3.2858362323413592, 0, 0, 0, 0]
# Guessed letter: n
# Current word: _ _ n _ e _ _ e _
# t 1.07, i 1.01, s 0.94, a 0.91, d 0.83, o 0.75, l 0.71, c 0.6, g 0.48, u 0.39, m 0.38, p 0.35, h 0.3, v 0.21, b 0.21, y 0.16, f 0.16, k 0.14, w 0.11, z 0.07, x 0.05, j 0.03, q 0.02,
# contributions: [4.4885760462662345, 4.505833547878591, 0.8809965380811078, 0, 0, 0]
# Wrong guess, you have 4 tries left
# Guessed letter: t
# Current word: _ _ n _ e _ _ e _
# i 1.01, s 0.94, a 0.91, d 0.83, o 0.75, l 0.71, c 0.6, g 0.48, u 0.39, m 0.38, p 0.35, h 0.3, v 0.21, b 0.21, y 0.16, f 0.16, k 0.14, w 0.11, z 0.07, x 0.05, j 0.03, q 0.02,
# contributions: [4.100924063393929, 4.036559027988814, 0.6690158259149357, 0, 0, 0]
# Wrong guess, you have 3 tries left
# Guessed letter: i
# Current word: _ _ n _ e _ _ e _
# s 0.94, a 0.91, d 0.83, o 0.75, l 0.71, c 0.6, g 0.48, u 0.39, m 0.38, p 0.35, h 0.3, v 0.21, b 0.21, y 0.16, f 0.16, k 0.14, w 0.11, z 0.07, x 0.05, j 0.03, q 0.02,
# contributions: [3.5792259404182887, 3.577006967386879, 0.6423714144411473, 0, 0, 0]
# Wrong guess, you have 2 tries left
# Guessed letter: s
# Current word: _ _ n _ e _ _ e _
# a 0.91, d 0.83, o 0.75, l 0.71, c 0.6, g 0.48, u 0.39, m 0.38, p 0.35, h 0.3, v 0.21, b 0.21, y 0.16, f 0.16, k 0.14, w 0.11, z 0.07, x 0.05, j 0.03, q 0.02,
# contributions: [3.159989005744687, 3.1107802505915543, 0.592482690405539, 0, 0, 0]
# Guessed letter: a
# Current word: _ a n _ e _ _ e _
# d 1.14, c 1.06, l 0.85, g 0.73, o 0.57, m 0.55, p 0.41, h 0.41, u 0.29, b 0.26, v 0.24, k 0.22, f 0.18, y 0.17, w 0.13, z 0.08, x 0.06, j 0.04, q 0.02,
# contributions: [2.2101277046762315, 2.93857475311184, 1.5782654712060322, 0.6897643334505804, 0, 0]
# Guessed letter: d
# Current word: _ a n _ e _ _ e d
# c 1.01, l 0.81, g 0.73, m 0.53, o 0.49, h 0.42, p 0.4, b 0.25, u 0.25, v 0.24, k 0.24, f 0.17, y 0.15, w 0.13, z 0.11, x 0.05, j 0.04, q 0.02,
# contributions: [1.6271799076218996, 2.1879036075907137, 1.6742383328737305, 0.527963418923672, 0, 0]
# Guessed letter: c
# Current word: c a n c e _ _ e d
# l 0.71, p 0.43, m 0.28, o 0.25, h 0.16, g 0.13, b 0.11, u 0.11, v 0.11, f 0.09, y 0.08, k 0.08, w 0.07, z 0.06, x 0.03, j 0.01, q 0.01,
# contributions: [0.7294697813291565, 0.7003008003088841, 0.7192453343849439, 0.2966023875114784, 0.2816091954022989, 0]
# You won!

# %% [markdown]
# ## Playing practice games:
# You can use the command below to play up to 100,000 practice games.

# %%
[total_practice_runs_,total_recorded_runs,total_recorded_successes,total_practice_successes_] = api.my_status()
for _ in range(100):
    api.start_game(practice=1,verbose=True)
    [total_practice_runs,total_recorded_runs,total_recorded_successes,total_practice_successes] = api.my_status() # Get my game stats: (# of tries, # of wins)
    # practice_success_rate = total_practice_successes / total_practice_runs
    print('practice success rate so far = ' , (total_practice_successes-total_practice_successes_)/(total_practice_runs-total_practice_runs_))
print(total_practice_successes-total_practice_successes_)
# Out:
# Successfully start a new game! Game ID: 70ce76799099. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ .
# e 0.99, i 0.78, a 0.76, n 0.64, o 0.64, r 0.63, s 0.63, t 0.58, l 0.52, c 0.38, u 0.33, d 0.32, p 0.28, m 0.26, h 0.25, g 0.22, y 0.17, b 0.17, f 0.11, v 0.09, k 0.08, w 0.08, z 0.04, x 0.03, q 0.02, j 0.02,
# contributions: [9.000000000000002, 0, 0, 0, 0, 0]
# Guessing letter: e
# Sever response: {'game_id': '70ce76799099', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ _ _ _ _ '}
# r 0.87, n 0.78, s 0.76, i 0.75, a 0.74, t 0.69, l 0.63, o 0.59, d 0.46, c 0.42, m 0.32, p 0.32, u 0.31, h 0.28, g 0.24, b 0.19, y 0.17, v 0.14, f 0.13, k 0.1, w 0.09, z 0.05, x 0.04, j 0.02, q 0.02,
# contributions: [7.119913627322986, 1.9488185499908894, 0, 0, 0, 0]
# Guessing letter: r
# Sever response: {'game_id': '70ce76799099', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ r _ _ _ _ '}
# a 0.95, i 0.85, o 0.78, t 0.75, s 0.74, n 0.73, l 0.59, d 0.47, c 0.43, u 0.37, p 0.36, m 0.32, h 0.28, g 0.26, b 0.21, y 0.19, v 0.14, f 0.14, k 0.1, w 0.09, z 0.05, x 0.04, j 0.02, q 0.02,
# contributions: [5.738291071026841, 3.1268374756705084, 0, 0, 0, 0]
# Guessing letter: a
# Sever response: {'game_id': '70ce76799099', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ _ r _ _ _ _ '}
# i 0.85, o 0.78, t 0.75, s 0.74, n 0.73, l 0.59, d 0.47, c 0.43, u 0.37, p 0.36, m 0.32, h 0.28, g 0.26, b 0.21, y 0.19, v 0.14, f 0.14, k 0.1, w 0.09, z 0.05, x 0.04, j 0.02, q 0.02,
# contributions: [5.145816017538091, 2.7681281475844357, 0, 0, 0, 0]
# Guessing letter: i
# Sever response: {'game_id': '70ce76799099', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ _ r _ i _ _ '}
# t 1.04, n 1.0, s 0.89, o 0.84, l 0.75, d 0.62, c 0.57, m 0.46, p 0.41, u 0.37, g 0.33, h 0.32, b 0.27, v 0.22, y 0.19, f 0.18, k 0.14, w 0.11, z 0.08, x 0.04, j 0.02, q 0.02,
# contributions: [3.8890013206284397, 4.228846747514631, 0.7511678604796013, 0, 0, 0]
# Guessing letter: t
# Sever response: {'game_id': '70ce76799099', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e _ _ r _ i _ _ '}
# n 1.0, s 0.89, o 0.84, l 0.75, d 0.62, c 0.57, m 0.46, p 0.41, u 0.37, g 0.33, h 0.32, b 0.27, v 0.22, y 0.19, f 0.18, k 0.14, w 0.11, z 0.08, x 0.04, j 0.02, q 0.02,
# contributions: [3.5013493377561358, 3.701019640622026, 0.6261808367071524, 0, 0, 0]
# Guessing letter: n
# Sever response: {'game_id': '70ce76799099', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e _ _ r _ i n _ '}
# g 0.92, s 0.88, o 0.85, l 0.83, d 0.78, m 0.61, c 0.57, p 0.42, h 0.39, u 0.38, b 0.29, v 0.26, k 0.23, y 0.23, f 0.21, w 0.15, z 0.08, x 0.05, j 0.02, q 0.02,
# contributions: [2.559491816904235, 3.1362274830157286, 1.874649681042068, 0.5817655571635311, 0, 0]
# Guessing letter: g
# Sever response: {'game_id': '70ce76799099', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e _ _ r _ i n g '}
# l 0.96, s 0.81, d 0.76, m 0.7, o 0.67, c 0.49, p 0.43, h 0.39, k 0.33, u 0.33, y 0.33, v 0.31, b 0.29, f 0.19, w 0.17, z 0.12, x 0.05, j 0.02, q 0.01,
# contributions: [1.9499817860581934, 2.4915786769941732, 1.1519337987183988, 1.1525994461046933, 0.6068376068376068, 0]
# Guessing letter: l
# Sever response: {'game_id': '70ce76799099', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e _ _ r _ i n g '}
# s 0.81, d 0.76, m 0.7, o 0.67, c 0.49, p 0.43, h 0.39, k 0.33, u 0.33, y 0.33, v 0.31, b 0.29, f 0.19, w 0.17, z 0.12, x 0.05, j 0.02, q 0.01,
# contributions: [1.7194958832726361, 2.1984510810444347, 0.9895076159246289, 0.9685084849733818, 0.5213675213675213, 0]
# Guessing letter: s
# Sever response: {'game_id': '70ce76799099', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e s _ r _ i n g '}
# o 0.81, c 0.76, m 0.71, d 0.66, p 0.57, h 0.53, u 0.51, k 0.34, y 0.33, v 0.31, b 0.3, f 0.18, w 0.18, z 0.12, x 0.03, q 0.02, j 0.02,
# contributions: [1.0800034451176754, 1.9375945881844323, 1.6973553225528422, 1.1878425517460534, 0.485042735042735, 0]
# Guessing letter: o
# Sever response: {'game_id': '70ce76799099', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ e s _ r _ i n g '}
# c 0.76, m 0.71, d 0.66, p 0.57, h 0.53, u 0.51, k 0.34, y 0.33, v 0.31, b 0.3, f 0.18, w 0.18, z 0.12, x 0.03, q 0.02, j 0.02,
# contributions: [0.8681400035580722, 1.596406127157711, 1.5126443658594761, 1.1211197777231412, 0.4818376068376068, 0]
# Guessing letter: c
# Sever response: {'game_id': '70ce76799099', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ e s c r _ i n g '}
# d 1.26, y 0.99, u 0.93, m 0.65, b 0.35, h 0.35, k 0.33, v 0.33, p 0.31, f 0.16, w 0.15, z 0.12, x 0.03, j 0.02, q 0.0,
# contributions: [0.49463982989025507, 0.913909047429087, 1.1041805012444172, 1.6205511501679322, 1.845032745032745, 0]
# Guessing letter: d
# Sever response: {'game_id': '70ce76799099', 'status': 'ongoing', 'tries_remains': 2, 'word': 'd e s c r _ i n g '}
# y 0.96, u 0.86, m 0.53, k 0.28, h 0.23, v 0.22, p 0.2, b 0.17, w 0.12, f 0.12, z 0.09, x 0.02, j 0.01, q 0.0,
# contributions: [0.21208935091535647, 0.4527448550517779, 0.7709361737143742, 1.1605478195975683, 1.20031635031635, 0]
# Guessing letter: y
# Sever response: {'game_id': '70ce76799099', 'status': 'success', 'tries_remains': 2, 'word': 'd e s c r y i n g '}
# Successfully finished game: 70ce76799099
# practice success rate so far =  1.0
# Successfully start a new game! Game ID: e2eedb230fc0. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ .
# e 0.99, i 0.78, a 0.76, n 0.64, o 0.64, r 0.63, s 0.63, t 0.58, l 0.52, c 0.38, u 0.33, d 0.32, p 0.28, m 0.26, h 0.25, g 0.22, y 0.17, b 0.17, f 0.11, v 0.09, k 0.08, w 0.08, z 0.04, x 0.03, q 0.02, j 0.02,
# contributions: [9.000000000000002, 0, 0, 0, 0, 0]
# Guessing letter: e
# Sever response: {'game_id': 'e2eedb230fc0', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ _ _ e '}
# i 0.73, a 0.69, r 0.67, n 0.66, t 0.63, s 0.62, o 0.57, l 0.56, c 0.38, d 0.34, u 0.3, p 0.29, m 0.28, h 0.27, g 0.23, b 0.18, y 0.16, v 0.13, f 0.11, k 0.09, w 0.08, z 0.05, x 0.03, j 0.02, q 0.02,
# contributions: [7.119913627322986, 0.9759377023299539, 0, 0, 0, 0]
# Guessing letter: i
# Sever response: {'game_id': 'e2eedb230fc0', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ i _ i _ e '}
# n 1.38, t 1.27, l 0.98, s 0.97, r 0.89, c 0.73, a 0.71, d 0.65, o 0.61, m 0.47, v 0.39, p 0.38, h 0.33, g 0.32, u 0.27, b 0.27, f 0.26, z 0.25, k 0.18, y 0.13, w 0.1, x 0.05, j 0.02, q 0.01,
# contributions: [4.8182370975165965, 4.806585681497961, 1.998491178778211, 0, 0, 0]
# Guessing letter: n
# Sever response: {'game_id': 'e2eedb230fc0', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ i _ i _ e '}
# t 1.27, l 0.98, s 0.97, r 0.89, c 0.73, a 0.71, d 0.65, o 0.61, m 0.47, v 0.39, p 0.38, h 0.33, g 0.32, u 0.27, b 0.27, f 0.26, z 0.25, k 0.18, y 0.13, w 0.1, x 0.05, j 0.02, q 0.01,
# contributions: [4.388277940045536, 4.158976756674673, 1.6918556576732522, 0, 0, 0]
# Guessing letter: t
# Sever response: {'game_id': 'e2eedb230fc0', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ i _ i t e '}
# l 1.65, r 1.13, s 0.89, c 0.68, a 0.59, m 0.56, d 0.56, o 0.49, h 0.38, b 0.36, p 0.36, g 0.31, v 0.29, u 0.28, f 0.22, k 0.14, z 0.13, y 0.12, w 0.11, x 0.05, j 0.02, q 0.01,
# contributions: [3.333854964311027, 2.1723863400532633, 1.5261760727433775, 1.6523317213040274, 0.6433823529411764, 0]
# Guessing letter: l
# Sever response: {'game_id': 'e2eedb230fc0', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ i _ i t e '}
# r 1.13, s 0.89, c 0.68, a 0.59, m 0.56, d 0.56, o 0.49, h 0.38, b 0.36, p 0.36, g 0.31, v 0.29, u 0.28, f 0.22, k 0.14, z 0.13, y 0.12, w 0.11, x 0.05, j 0.02, q 0.01,
# contributions: [3.0457475858290817, 1.8974092201630912, 1.1715263309401287, 1.0575484366008057, 0.5036764705882353, 0]
# Guessing letter: r
# Sever response: {'game_id': 'e2eedb230fc0', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ r r i _ i t e '}
# a 1.22, c 1.13, s 0.98, d 0.89, o 0.87, m 0.74, g 0.61, f 0.55, u 0.5, b 0.47, v 0.43, p 0.42, h 0.3, z 0.24, k 0.18, w 0.11, y 0.1, x 0.05, j 0.02, q 0.01,
# contributions: [1.6167485431199777, 1.6720080916012277, 2.2544032506808165, 2.516317246440702, 1.7384990018440507, 0]
# Guessing letter: a
# Sever response: {'game_id': 'e2eedb230fc0', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ a r r i _ i t e '}
# c 1.64, s 1.11, m 1.1, d 0.95, b 0.84, g 0.76, p 0.64, f 0.62, h 0.56, v 0.52, o 0.44, w 0.29, z 0.26, u 0.26, k 0.22, y 0.08, j 0.08, x 0.05, q 0.01,
# contributions: [0.9085537753689147, 1.5253871574116795, 2.2076257894052254, 2.713912285199145, 3.0576699299258694, 0]
# Guessing letter: c
# Sever response: {'game_id': 'e2eedb230fc0', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ a r r i _ i t e '}
# s 1.11, m 1.1, d 0.95, b 0.84, g 0.76, p 0.64, f 0.62, h 0.56, v 0.52, o 0.44, w 0.29, z 0.26, u 0.26, k 0.22, y 0.08, j 0.08, x 0.05, q 0.01,
# contributions: [0.8244336028871215, 1.298677481985035, 1.8458252856865212, 2.2856727600247533, 2.5184012028860696, 0]
# Guessing letter: s
# Sever response: {'game_id': 'e2eedb230fc0', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ a r r i s i t e '}
# b 0.42, m 0.41, p 0.34, h 0.33, g 0.2, w 0.2, u 0.13, d 0.12, o 0.11, f 0.1, j 0.06, v 0.05, y 0.05, k 0.05, z 0.03, x 0.01, q 0.0,
# contributions: [0.3423439789979602, 0.39300817250229036, 0.5283513602097674, 0.6434474616292799, 0.6813186813186813, 0]
# Guessing letter: b
# Sever response: {'game_id': 'e2eedb230fc0', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ a r r i s i t e '}
# m 0.41, p 0.34, h 0.33, g 0.2, w 0.2, u 0.13, d 0.12, o 0.11, f 0.1, j 0.06, v 0.05, y 0.05, k 0.05, z 0.03, x 0.01, q 0.0,
# contributions: [0.3235935024704129, 0.36014828207570637, 0.47361520812848246, 0.46635182998819363, 0.543956043956044, 0]
# Guessing letter: m
# Sever response: {'game_id': 'e2eedb230fc0', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ a r r i s i t e '}
# p 0.34, h 0.33, g 0.2, w 0.2, u 0.13, d 0.12, o 0.11, f 0.1, j 0.06, v 0.05, y 0.05, k 0.05, z 0.03, x 0.01, q 0.0,
# contributions: [0.2943236509210983, 0.286984061497018, 0.40402053971375507, 0.3872491145218418, 0.38461538461538464, 0]
# Guessing letter: p
# Sever response: {'game_id': 'e2eedb230fc0', 'status': 'failed', 'tries_remains': 0, 'word': '_ a r r i s i t e '}
# Failed game: e2eedb230fc0. Because of: # of tries exceeded!
# practice success rate so far =  0.5
# Successfully start a new game! Game ID: b1e7e513b9a9. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ .
# e 0.99, i 0.78, a 0.76, n 0.64, o 0.64, r 0.63, s 0.63, t 0.58, l 0.52, c 0.38, u 0.33, d 0.32, p 0.28, m 0.26, h 0.25, g 0.22, y 0.17, b 0.17, f 0.11, v 0.09, k 0.08, w 0.08, z 0.04, x 0.03, q 0.02, j 0.02,
# contributions: [9.000000000000002, 0, 0, 0, 0, 0]
# Guessing letter: e
# Sever response: {'game_id': 'b1e7e513b9a9', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ e _ _ e _ '}
# r 1.34, n 1.04, s 1.01, t 0.9, l 0.85, d 0.74, a 0.71, i 0.67, o 0.49, c 0.49, m 0.43, p 0.4, h 0.33, u 0.29, g 0.28, v 0.24, b 0.22, y 0.16, f 0.15, k 0.13, w 0.12, z 0.08, x 0.07, j 0.02, q 0.02,
# contributions: [5.339935220492236, 5.8464556499726745, 0, 0, 0, 0]
# Guessing letter: r
# Sever response: {'game_id': 'b1e7e513b9a9', 'status': 'ongoing', 'tries_remains': 6, 'word': 'r e _ r e _ _ e _ '}
# p 1.49, t 1.35, a 1.35, d 1.05, s 1.04, n 0.91, c 0.89, o 0.67, l 0.64, g 0.63, i 0.6, b 0.48, u 0.45, f 0.43, m 0.36, h 0.25, v 0.18, y 0.14, w 0.14, k 0.08, x 0.07, z 0.04, q 0.02, j 0.02,
# contributions: [3.279023469158195, 3.888623091052874, 3.3972206343051163, 1.7211358789286335, 0.978813559322034, 0]
# Guessing letter: p
# Sever response: {'game_id': 'b1e7e513b9a9', 'status': 'ongoing', 'tries_remains': 5, 'word': 'r e _ r e _ _ e _ '}
# t 1.35, a 1.35, d 1.05, s 1.04, n 0.91, c 0.89, o 0.67, l 0.64, g 0.63, i 0.6, b 0.48, u 0.45, f 0.43, m 0.36, h 0.25, v 0.18, y 0.14, w 0.14, k 0.08, x 0.07, z 0.04, q 0.02, j 0.02,
# contributions: [3.155178077756117, 3.7060244300905127, 3.0456548558142726, 1.3121033417579329, 0.559322033898305, 0]
# Guessing letter: t
# Sever response: {'game_id': 'b1e7e513b9a9', 'status': 'ongoing', 'tries_remains': 5, 'word': 'r e t r e _ _ e _ '}
# s 0.99, a 0.9, n 0.81, d 0.62, l 0.5, c 0.41, i 0.38, m 0.36, o 0.28, g 0.2, h 0.16, u 0.16, v 0.15, b 0.14, f 0.12, y 0.1, k 0.09, w 0.09, z 0.05, x 0.05, j 0.02, q 0.02,
# contributions: [2.172557566880935, 2.1001959171630284, 0.7911373195161082, 0.7628596338273759, 0.7681159420289856, 0]
# Guessing letter: s
# Sever response: {'game_id': 'b1e7e513b9a9', 'status': 'ongoing', 'tries_remains': 4, 'word': 'r e t r e _ _ e _ '}
# a 0.9, n 0.81, d 0.62, l 0.5, c 0.41, i 0.38, m 0.36, o 0.28, g 0.2, h 0.16, u 0.16, v 0.15, b 0.14, f 0.12, y 0.1, k 0.09, w 0.09, z 0.05, x 0.05, j 0.02, q 0.02,
# contributions: [1.9629390995441331, 1.7677688535757408, 0.6455794996314443, 0.5571054925893637, 0.6666666666666667, 0]
# Guessing letter: a
# Sever response: {'game_id': 'b1e7e513b9a9', 'status': 'ongoing', 'tries_remains': 4, 'word': 'r e t r e a _ e _ '}
# d 1.12, n 0.74, l 0.72, m 0.69, c 0.59, k 0.47, v 0.41, g 0.28, i 0.25, b 0.2, o 0.17, u 0.16, h 0.13, f 0.11, y 0.08, w 0.06, z 0.05, x 0.04, j 0.01, q 0.01,
# contributions: [1.1393474796516854, 1.761908205187352, 1.115682857952978, 1.2427566032187027, 1.030364818692825, 0]
# Guessing letter: d
# Sever response: {'game_id': 'b1e7e513b9a9', 'status': 'success', 'tries_remains': 4, 'word': 'r e t r e a d e d '}
# Successfully finished game: b1e7e513b9a9
# practice success rate so far =  0.6666666666666666
# Successfully start a new game! Game ID: b1592a2f0398. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ .
# e 1.21, i 0.96, a 0.93, n 0.79, o 0.78, r 0.77, s 0.77, t 0.71, l 0.63, c 0.46, u 0.4, d 0.39, p 0.34, m 0.32, h 0.3, g 0.27, y 0.21, b 0.21, f 0.14, v 0.11, k 0.1, w 0.09, z 0.05, x 0.03, q 0.02, j 0.02,
# contributions: [10.999999999999986, 0, 0, 0, 0, 0]
# Guessing letter: e
# Sever response: {'game_id': 'b1592a2f0398', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ _ _ '}
# i 0.96, a 0.93, n 0.79, o 0.78, r 0.77, s 0.77, t 0.71, l 0.63, c 0.46, u 0.4, d 0.39, p 0.34, m 0.32, h 0.3, g 0.27, y 0.21, b 0.21, f 0.14, v 0.11, k 0.1, w 0.09, z 0.05, x 0.03, q 0.02, j 0.02,
# contributions: [9.789881237569103, 0, 0, 0, 0, 0]
# Guessing letter: i
# Sever response: {'game_id': 'b1592a2f0398', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ i _ _ _ _ _ _ '}
# n 1.0, a 0.94, t 0.88, s 0.87, r 0.85, o 0.79, l 0.74, c 0.57, d 0.46, u 0.39, m 0.38, p 0.37, h 0.33, g 0.3, b 0.23, y 0.2, f 0.17, v 0.15, k 0.11, w 0.1, z 0.07, x 0.04, q 0.02, j 0.02,
# contributions: [8.030395162527668, 1.9337299177962248, 0, 0, 0, 0]
# Guessing letter: n
# Sever response: {'game_id': 'b1592a2f0398', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ n _ i _ _ _ _ _ _ '}
# t 1.25, a 1.13, o 1.02, s 0.97, r 0.82, l 0.73, c 0.66, d 0.65, g 0.49, u 0.47, m 0.37, p 0.35, h 0.32, b 0.23, f 0.2, y 0.2, v 0.19, k 0.14, w 0.12, z 0.08, x 0.04, j 0.02, q 0.02,
# contributions: [6.582416910068312, 2.9501537518496224, 0.9227551318221618, 0, 0, 0]
# Guessing letter: t
# Sever response: {'game_id': 'b1592a2f0398', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ n _ i _ _ _ _ _ _ '}
# a 1.13, o 1.02, s 0.97, r 0.82, l 0.73, c 0.66, d 0.65, g 0.49, u 0.47, m 0.37, p 0.35, h 0.32, b 0.23, f 0.2, y 0.2, v 0.19, k 0.14, w 0.12, z 0.08, x 0.04, j 0.02, q 0.02,
# contributions: [6.00093893575985, 2.587358696969021, 0.6150403735771962, 0, 0, 0]
# Guessing letter: a
# Sever response: {'game_id': 'b1592a2f0398', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ a n _ i a _ a _ _ _ '}
# r 1.62, l 1.58, c 1.47, d 1.32, s 1.19, g 0.92, m 0.84, o 0.68, p 0.57, h 0.5, b 0.49, u 0.36, v 0.31, k 0.24, f 0.23, y 0.22, w 0.18, z 0.11, x 0.07, j 0.05, q 0.02,
# contributions: [3.492790197040022, 4.032220191204986, 3.883431782311817, 1.297739918558549, 0.27488151658767773, 0]
# Guessing letter: r
# Sever response: {'game_id': 'b1592a2f0398', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ a n _ i a _ a _ _ _ '}
# l 1.58, c 1.47, d 1.32, s 1.19, g 0.92, m 0.84, o 0.68, p 0.57, h 0.5, b 0.49, u 0.36, v 0.31, k 0.24, f 0.23, y 0.22, w 0.18, z 0.11, x 0.07, j 0.05, q 0.02,
# contributions: [3.0713901802850803, 3.422036684952744, 3.3433309541257876, 1.2514537531250527, 0.27488151658767773, 0]
# Guessing letter: l
# Sever response: {'game_id': 'b1592a2f0398', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ a n _ i a _ a l l _ '}
# c 2.79, d 1.39, s 1.23, g 1.08, y 1.04, m 0.94, o 0.86, b 0.63, p 0.61, h 0.59, v 0.48, u 0.4, f 0.27, w 0.26, k 0.24, z 0.11, x 0.09, j 0.05, q 0.02,
# contributions: [1.817107550737831, 2.7812826904052894, 3.846611182549032, 3.1230919777804163, 1.5304603836485209, 0]
# Guessing letter: c
# Sever response: {'game_id': 'b1592a2f0398', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ a n _ i a c a l l _ '}
# y 1.87, d 1.65, s 0.99, g 0.89, o 0.84, m 0.54, h 0.39, p 0.33, b 0.29, u 0.28, v 0.2, f 0.19, k 0.17, w 0.11, z 0.06, x 0.04, j 0.03, q 0.01,
# contributions: [1.2366504043306827, 1.688131165672037, 2.228442910823511, 1.688027041955474, 2.041756643968704, 0]
# Guessing letter: y
# Sever response: {'game_id': 'b1592a2f0398', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ a n _ i a c a l l y '}
# d 1.58, g 0.86, s 0.85, m 0.49, o 0.44, h 0.35, p 0.27, b 0.24, v 0.18, u 0.15, k 0.15, f 0.15, w 0.09, z 0.05, x 0.04, j 0.03, q 0.01,
# contributions: [0.7858548739472859, 1.3297244574888478, 1.7329275203315797, 0.9699446764630162, 1.1010252442209112, 0]
# Guessing letter: d
# Sever response: {'game_id': 'b1592a2f0398', 'status': 'success', 'tries_remains': 3, 'word': 'd a n d i a c a l l y '}
# Successfully finished game: b1592a2f0398
# practice success rate so far =  0.75
# Successfully start a new game! Game ID: b63d1f87ea42. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ .
# e 0.88, i 0.7, a 0.68, n 0.57, o 0.56, r 0.56, s 0.56, t 0.52, l 0.46, c 0.34, u 0.29, d 0.28, p 0.25, m 0.23, h 0.22, g 0.2, y 0.15, b 0.15, f 0.1, v 0.08, k 0.07, w 0.07, z 0.03, x 0.02, q 0.02, j 0.01,
# contributions: [8.000000000000004, 0, 0, 0, 0, 0]
# Guessing letter: e
# Sever response: {'game_id': 'b63d1f87ea42', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ '}
# i 0.7, a 0.68, n 0.57, o 0.56, r 0.56, s 0.56, t 0.52, l 0.46, c 0.34, u 0.29, d 0.28, p 0.25, m 0.23, h 0.22, g 0.2, y 0.15, b 0.15, f 0.1, v 0.08, k 0.07, w 0.07, z 0.03, x 0.02, q 0.02, j 0.01,
# contributions: [7.119913627322986, 0, 0, 0, 0, 0]
# Guessing letter: i
# Sever response: {'game_id': 'b63d1f87ea42', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ i _ _ _ _ '}
# n 0.78, t 0.69, a 0.68, s 0.66, r 0.64, o 0.58, l 0.57, c 0.44, d 0.35, m 0.29, u 0.28, p 0.27, h 0.24, g 0.22, b 0.17, y 0.14, f 0.13, v 0.12, k 0.09, w 0.08, z 0.06, x 0.03, q 0.01, j 0.01,
# contributions: [5.621276613769365, 1.9337299177962248, 0, 0, 0, 0]
# Guessing letter: n
# Sever response: {'game_id': 'b63d1f87ea42', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ i n _ _ _ '}
# t 0.88, g 0.77, a 0.72, r 0.64, s 0.63, l 0.58, o 0.58, d 0.44, c 0.41, m 0.32, p 0.27, u 0.27, h 0.27, b 0.17, f 0.15, y 0.15, k 0.14, v 0.13, w 0.11, z 0.06, x 0.03, j 0.02, q 0.02,
# contributions: [4.388277940045536, 1.6469823073975776, 1.7215690918006492, 0, 0, 0]
# Guessing letter: t
# Sever response: {'game_id': 'b63d1f87ea42', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ t i n _ _ _ '}
# a 1.42, g 1.34, s 0.87, o 0.64, c 0.51, r 0.5, l 0.36, u 0.34, d 0.3, p 0.23, h 0.18, m 0.16, y 0.13, f 0.12, b 0.11, k 0.08, v 0.07, w 0.05, x 0.03, z 0.02, q 0.01, j 0.01,
# contributions: [3.333854964311027, 1.2433291156450692, 1.4142341988971854, 1.5255531413637793, 0, 0]
# Guessing letter: a
# Sever response: {'game_id': 'b63d1f87ea42', 'status': 'ongoing', 'tries_remains': 5, 'word': 'a _ t i n _ a _ '}
# g 1.59, s 1.54, c 1.34, r 1.1, l 0.8, u 0.66, o 0.55, d 0.53, p 0.39, m 0.33, h 0.3, f 0.27, b 0.22, k 0.17, y 0.15, v 0.15, w 0.13, z 0.05, x 0.04, j 0.03, q 0.01,
# contributions: [1.746395098520011, 3.0227865821626074, 2.1280576547746706, 2.2685130329022463, 1.1787003610108304, 0]
# Guessing letter: g
# Sever response: {'game_id': 'b63d1f87ea42', 'status': 'ongoing', 'tries_remains': 4, 'word': 'a _ t i n _ a _ '}
# s 1.54, c 1.34, r 1.1, l 0.8, u 0.66, o 0.55, d 0.53, p 0.39, m 0.33, h 0.3, f 0.27, b 0.22, k 0.17, y 0.15, v 0.15, w 0.13, z 0.05, x 0.04, j 0.03, q 0.01,
# contributions: [1.6731863479211166, 2.7921584433066573, 1.6494875798908923, 1.5517454157015809, 1.0868636263169529, 0]
# Guessing letter: s
# Sever response: {'game_id': 'b63d1f87ea42', 'status': 'ongoing', 'tries_remains': 3, 'word': 'a _ t i n _ a _ '}
# c 1.34, r 1.1, l 0.8, u 0.66, o 0.55, d 0.53, p 0.39, m 0.33, h 0.3, f 0.27, b 0.22, k 0.17, y 0.15, v 0.15, w 0.13, z 0.05, x 0.04, j 0.03, q 0.01,
# contributions: [1.4635678805843146, 2.408913578638588, 1.246780013309253, 1.2126946827006349, 0.8792823988801298, 0]
# Guessing letter: c
# Sever response: {'game_id': 'b63d1f87ea42', 'status': 'ongoing', 'tries_remains': 3, 'word': 'a _ t i n c a _ '}
# r 1.56, l 1.16, p 0.58, u 0.41, o 0.28, m 0.22, x 0.2, b 0.18, d 0.18, v 0.15, f 0.13, y 0.11, h 0.11, k 0.07, w 0.04, z 0.02, j 0.01, q 0.01,
# contributions: [0.8915917479077499, 1.2513406229919473, 1.12900127929472, 1.0069526285817465, 1.1358530676344694, 0]
# Guessing letter: r
# Sever response: {'game_id': 'b63d1f87ea42', 'status': 'ongoing', 'tries_remains': 3, 'word': 'a _ t i n c a r '}
# l 0.4, u 0.25, o 0.21, x 0.2, p 0.19, f 0.1, d 0.08, m 0.07, y 0.07, b 0.07, h 0.07, k 0.03, v 0.02, w 0.02, z 0.01, q 0.0, j 0.0,
# contributions: [0.375562537828051, 0.5807469397086736, 0.28897372067885885, 0.23769384835479251, 0.307170422009212, 0]
# Guessing letter: l
# Sever response: {'game_id': 'b63d1f87ea42', 'status': 'success', 'tries_remains': 3, 'word': 'a l t i n c a r '}
# Successfully finished game: b63d1f87ea42
# practice success rate so far =  0.8
# Successfully start a new game! Game ID: 1f78adfb79b4. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ .
# e 0.88, i 0.7, a 0.68, n 0.57, o 0.56, r 0.56, s 0.56, t 0.52, l 0.46, c 0.34, u 0.29, d 0.28, p 0.25, m 0.23, h 0.22, g 0.2, y 0.15, b 0.15, f 0.1, v 0.08, k 0.07, w 0.07, z 0.03, x 0.02, q 0.02, j 0.01,
# contributions: [8.000000000000004, 0, 0, 0, 0, 0]
# Guessing letter: e
# Sever response: {'game_id': '1f78adfb79b4', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ '}
# i 0.7, a 0.68, n 0.57, o 0.56, r 0.56, s 0.56, t 0.52, l 0.46, c 0.34, u 0.29, d 0.28, p 0.25, m 0.23, h 0.22, g 0.2, y 0.15, b 0.15, f 0.1, v 0.08, k 0.07, w 0.07, z 0.03, x 0.02, q 0.02, j 0.01,
# contributions: [7.119913627322986, 0, 0, 0, 0, 0]
# Guessing letter: i
# Sever response: {'game_id': '1f78adfb79b4', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ i _ i _ _ '}
# n 1.11, t 1.03, l 0.83, s 0.83, r 0.75, a 0.69, c 0.64, o 0.6, d 0.5, m 0.39, p 0.32, h 0.27, g 0.27, u 0.26, b 0.23, f 0.23, v 0.21, z 0.13, y 0.13, k 0.11, w 0.09, x 0.04, j 0.02, q 0.01,
# contributions: [4.8182370975165965, 3.8674598355924483, 0.9988121287902471, 0, 0, 0]
# Guessing letter: n
# Sever response: {'game_id': '1f78adfb79b4', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ i _ i n _ '}
# t 1.29, s 0.98, l 0.92, g 0.84, r 0.79, a 0.73, d 0.67, c 0.66, o 0.6, m 0.48, z 0.34, p 0.33, h 0.3, v 0.27, u 0.26, f 0.25, b 0.23, k 0.19, y 0.14, w 0.12, x 0.05, j 0.02, q 0.02,
# contributions: [3.656898283371282, 3.300331651242368, 2.5996559939575747, 0.9035821894877804, 0, 0]
# Guessing letter: t
# Sever response: {'game_id': '1f78adfb79b4', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ i t i n _ '}
# g 2.18, r 0.84, l 0.75, s 0.74, a 0.67, o 0.54, d 0.51, c 0.44, m 0.37, u 0.31, h 0.31, b 0.28, p 0.26, v 0.17, f 0.15, k 0.11, y 0.1, w 0.09, x 0.04, z 0.03, j 0.01, q 0.01,
# contributions: [2.6670839714488217, 1.3656998037780652, 1.5475573194257923, 1.611970811057391, 1.7295118390147908, 0]
# Guessing letter: g
# Sever response: {'game_id': '1f78adfb79b4', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ i t i n g '}
# r 0.76, l 0.68, s 0.53, a 0.38, d 0.36, m 0.33, c 0.29, o 0.29, h 0.27, b 0.25, u 0.23, p 0.22, v 0.14, f 0.1, w 0.07, y 0.07, k 0.06, x 0.03, z 0.02, j 0.01, q 0.01,
# contributions: [1.927104227987721, 0.7259113444975267, 0.8044447590062992, 0.763372298972724, 0.8707865168539325, 0]
# Guessing letter: r
# Sever response: {'game_id': '1f78adfb79b4', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ i t i n g '}
# l 0.68, s 0.53, a 0.38, d 0.36, m 0.33, c 0.29, o 0.29, h 0.27, b 0.25, u 0.23, p 0.22, v 0.14, f 0.1, w 0.07, y 0.07, k 0.06, x 0.03, z 0.02, j 0.01, q 0.01,
# contributions: [1.7164042196102498, 0.6081458376811267, 0.6916979262509731, 0.6216790648246545, 0.6910112359550562, 0]
# Guessing letter: l
# Sever response: {'game_id': '1f78adfb79b4', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ i t i n g '}
# s 0.53, a 0.38, d 0.36, m 0.33, c 0.29, o 0.29, h 0.27, b 0.25, u 0.23, p 0.22, v 0.14, f 0.1, w 0.07, y 0.07, k 0.06, x 0.03, z 0.02, j 0.01, q 0.01,
# contributions: [1.5435397925210825, 0.49983924915253286, 0.4914714417156204, 0.44349982288345724, 0.6741573033707866, 0]
# Guessing letter: s
# Sever response: {'game_id': '1f78adfb79b4', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ _ i t i n g '}
# a 0.38, d 0.36, m 0.33, c 0.29, o 0.29, h 0.27, b 0.25, u 0.23, p 0.22, v 0.14, f 0.1, w 0.07, y 0.07, k 0.06, x 0.03, z 0.02, j 0.01, q 0.01,
# contributions: [1.3339213251842807, 0.4375581664250704, 0.42387996319626303, 0.3173928444916755, 0.606741573033708, 0]
# Guessing letter: a
# Sever response: {'game_id': '1f78adfb79b4', 'status': 'ongoing', 'tries_remains': 2, 'word': 'a _ a i t i n g '}
# w 0.83, m 0.52, b 0.45, d 0.38, c 0.37, h 0.33, p 0.3, f 0.25, v 0.23, u 0.14, k 0.1, o 0.09, y 0.06, j 0.04, z 0.04, x 0.02, q 0.0,
# contributions: [0.3600011483725584, 0.7578279415980353, 0.7969560294907361, 1.0883912655971477, 1.1452380952380954, 0]
# Guessing letter: w
# Sever response: {'game_id': '1f78adfb79b4', 'status': 'success', 'tries_remains': 2, 'word': 'a w a i t i n g '}
# Successfully finished game: 1f78adfb79b4
# practice success rate so far =  0.8333333333333334
# Successfully start a new game! Game ID: c005cc1280ff. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ .
# e 0.99, i 0.78, a 0.76, n 0.64, o 0.64, r 0.63, s 0.63, t 0.58, l 0.52, c 0.38, u 0.33, d 0.32, p 0.28, m 0.26, h 0.25, g 0.22, y 0.17, b 0.17, f 0.11, v 0.09, k 0.08, w 0.08, z 0.04, x 0.03, q 0.02, j 0.02,
# contributions: [9.000000000000002, 0, 0, 0, 0, 0]
# Guessing letter: e
# Sever response: {'game_id': 'c005cc1280ff', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ _ _ _ e '}
# r 0.91, n 0.79, s 0.75, t 0.74, i 0.7, a 0.67, l 0.67, o 0.52, d 0.49, c 0.41, m 0.34, p 0.33, h 0.3, u 0.29, g 0.25, b 0.2, v 0.18, y 0.16, f 0.13, k 0.11, w 0.1, z 0.06, x 0.04, j 0.02, q 0.02,
# contributions: [6.229924423907611, 2.924756252320844, 0, 0, 0, 0]
# Guessing letter: r
# Sever response: {'game_id': 'c005cc1280ff', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ r _ _ e '}
# a 0.88, t 0.8, i 0.8, n 0.75, s 0.73, o 0.72, l 0.63, d 0.5, c 0.43, p 0.38, u 0.34, m 0.34, h 0.3, g 0.27, b 0.22, y 0.18, v 0.17, f 0.14, k 0.11, w 0.1, z 0.06, x 0.04, j 0.02, q 0.01,
# contributions: [4.91853520373729, 3.992796375527713, 0, 0, 0, 0]
# Guessing letter: a
# Sever response: {'game_id': 'c005cc1280ff', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ _ _ r _ _ e '}
# t 0.8, i 0.8, n 0.75, s 0.73, o 0.72, l 0.63, d 0.5, c 0.43, p 0.38, u 0.34, m 0.34, h 0.3, g 0.27, b 0.22, y 0.18, v 0.17, f 0.14, k 0.11, w 0.1, z 0.06, x 0.04, j 0.02, q 0.01,
# contributions: [4.410699443604079, 3.6192310398495553, 0, 0, 0, 0]
# Guessing letter: t
# Sever response: {'game_id': 'c005cc1280ff', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e _ _ _ r _ _ e '}
# i 0.8, n 0.75, s 0.73, o 0.72, l 0.63, d 0.5, c 0.43, p 0.38, u 0.34, m 0.34, h 0.3, g 0.27, b 0.22, y 0.18, v 0.17, f 0.14, k 0.11, w 0.1, z 0.06, x 0.04, j 0.02, q 0.01,
# contributions: [4.023047460731776, 3.2090128824094837, 0, 0, 0, 0]
# Guessing letter: i
# Sever response: {'game_id': 'c005cc1280ff', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e _ _ _ r i _ e '}
# n 1.36, s 0.98, c 0.75, d 0.74, o 0.73, l 0.71, p 0.49, m 0.43, v 0.41, z 0.38, u 0.36, g 0.35, b 0.33, h 0.3, f 0.23, k 0.17, y 0.14, w 0.09, x 0.05, j 0.02, q 0.01,
# contributions: [2.9177911147967794, 3.2669834591348494, 1.9997117654853303, 0.8377862595419847, 0, 0]
# Guessing letter: n
# Sever response: {'game_id': 'c005cc1280ff', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e _ _ _ r i _ e '}
# s 0.98, c 0.75, d 0.74, o 0.73, l 0.71, p 0.49, m 0.43, v 0.41, z 0.38, u 0.36, g 0.35, b 0.33, h 0.3, f 0.23, k 0.17, y 0.14, w 0.09, x 0.05, j 0.02, q 0.01,
# contributions: [2.559491816904235, 2.7617707832113467, 1.6522940265436192, 0.6858778625954199, 0, 0]
# Guessing letter: s
# Sever response: {'game_id': 'c005cc1280ff', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e _ _ _ r i s e '}
# o 0.78, p 0.55, u 0.46, l 0.4, d 0.4, c 0.36, h 0.27, g 0.24, b 0.23, m 0.2, f 0.14, y 0.13, v 0.1, w 0.08, k 0.08, z 0.03, x 0.03, j 0.01, q 0.01,
# contributions: [1.7681021637409846, 1.37679821078906, 0.4185873236638188, 0.4618220115850447, 0.4951923076923076, 0]
# Guessing letter: o
# Sever response: {'game_id': 'c005cc1280ff', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e o _ o r i s e '}
# l 2.08, m 1.4, d 1.05, c 0.94, p 0.91, h 0.68, g 0.5, u 0.43, b 0.37, f 0.3, v 0.17, w 0.17, z 0.1, k 0.08, y 0.07, j 0.05, x 0.04, q 0.01,
# contributions: [0.7428087874974231, 1.5573830796762247, 2.585709637559296, 2.112102745044892, 2.3556229211401627, 0]
# Guessing letter: l
# Sever response: {'game_id': 'c005cc1280ff', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ e o _ o r i s e '}
# m 1.4, d 1.05, c 0.94, p 0.91, h 0.68, g 0.5, u 0.43, b 0.37, f 0.3, v 0.17, w 0.17, z 0.1, k 0.08, y 0.07, j 0.05, x 0.04, q 0.01,
# contributions: [0.6275658361046449, 1.304273416669252, 2.070611448157957, 1.3233010591377359, 1.9514294134983792, 0]
# Guessing letter: m
# Sever response: {'game_id': 'c005cc1280ff', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ e o _ o r i s e '}
# d 1.05, c 0.94, p 0.91, h 0.68, g 0.5, u 0.43, b 0.37, f 0.3, v 0.17, w 0.17, z 0.1, k 0.08, y 0.07, j 0.05, x 0.04, q 0.01,
# contributions: [0.5690261330060158, 1.1400177854114102, 1.838900087113048, 0.9644453423914263, 1.3621994863374174, 0]
# Guessing letter: d
# Sever response: {'game_id': 'c005cc1280ff', 'status': 'success', 'tries_remains': 1, 'word': 'd e o d o r i s e '}
# Successfully finished game: c005cc1280ff
# practice success rate so far =  0.8571428571428571
# Successfully start a new game! Game ID: 48dc45a2be32. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ .
# e 0.99, i 0.78, a 0.76, n 0.64, o 0.64, r 0.63, s 0.63, t 0.58, l 0.52, c 0.38, u 0.33, d 0.32, p 0.28, m 0.26, h 0.25, g 0.22, y 0.17, b 0.17, f 0.11, v 0.09, k 0.08, w 0.08, z 0.04, x 0.03, q 0.02, j 0.02,
# contributions: [9.000000000000002, 0, 0, 0, 0, 0]
# Guessing letter: e
# Sever response: {'game_id': '48dc45a2be32', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ '}
# i 0.78, a 0.76, n 0.64, o 0.64, r 0.63, s 0.63, t 0.58, l 0.52, c 0.38, u 0.33, d 0.32, p 0.28, m 0.26, h 0.25, g 0.22, y 0.17, b 0.17, f 0.11, v 0.09, k 0.08, w 0.08, z 0.04, x 0.03, q 0.02, j 0.02,
# contributions: [8.00990283073836, 0, 0, 0, 0, 0]
# Guessing letter: i
# Sever response: {'game_id': '48dc45a2be32', 'status': 'ongoing', 'tries_remains': 5, 'word': 'i _ _ _ _ _ _ _ _ '}
# n 0.78, a 0.74, s 0.67, o 0.63, t 0.6, r 0.59, l 0.52, c 0.45, d 0.33, u 0.3, p 0.27, m 0.26, g 0.22, h 0.22, b 0.16, y 0.15, f 0.12, v 0.11, k 0.08, w 0.07, z 0.06, x 0.03, q 0.02, j 0.01,
# contributions: [6.424316130022134, 0.9521119182136133, 0, 0, 0, 0]
# Guessing letter: n
# Sever response: {'game_id': '48dc45a2be32', 'status': 'ongoing', 'tries_remains': 4, 'word': 'i _ _ _ _ _ _ _ _ '}
# a 0.74, s 0.67, o 0.63, t 0.6, r 0.59, l 0.52, c 0.45, d 0.33, u 0.3, p 0.27, m 0.26, g 0.22, h 0.22, b 0.16, y 0.15, f 0.12, v 0.11, k 0.08, w 0.07, z 0.06, x 0.03, q 0.02, j 0.01,
# contributions: [5.851037253394053, 0.7447799135796369, 0, 0, 0, 0]
# Guessing letter: a
# Sever response: {'game_id': '48dc45a2be32', 'status': 'ongoing', 'tries_remains': 4, 'word': 'i _ _ a _ a _ _ a '}
# r 1.15, l 1.03, t 1.01, c 0.73, s 0.72, m 0.56, o 0.46, d 0.44, p 0.42, h 0.34, b 0.33, g 0.33, u 0.28, v 0.2, y 0.16, f 0.15, w 0.14, k 0.13, z 0.09, x 0.04, j 0.03, q 0.01,
# contributions: [3.2337018165936064, 4.68268539487755, 0.8463203463203463, 0, 0, 0]
# Guessing letter: r
# Sever response: {'game_id': '48dc45a2be32', 'status': 'ongoing', 'tries_remains': 4, 'word': 'i _ _ a _ a r r a '}
# t 1.29, l 0.92, m 0.91, c 0.87, p 0.73, b 0.72, s 0.63, w 0.54, h 0.44, v 0.39, d 0.38, g 0.37, o 0.33, u 0.24, f 0.22, z 0.15, y 0.13, k 0.12, j 0.07, x 0.04, q 0.01,
# contributions: [1.7295210815786919, 2.6880871698596027, 1.5135805242402192, 1.7457909266137532, 1.8225806451612903, 0]
# Guessing letter: t
# Sever response: {'game_id': '48dc45a2be32', 'status': 'ongoing', 'tries_remains': 3, 'word': 'i _ _ a _ a r r a '}
# l 0.92, m 0.91, c 0.87, p 0.73, b 0.72, s 0.63, w 0.54, h 0.44, v 0.39, d 0.38, g 0.37, o 0.33, u 0.24, f 0.22, z 0.15, y 0.13, k 0.12, j 0.07, x 0.04, q 0.01,
# contributions: [1.5356950901425397, 2.319195908992214, 1.3434780707507978, 1.5944811658149416, 1.4212523719165084, 0]
# Guessing letter: l
# Sever response: {'game_id': '48dc45a2be32', 'status': 'ongoing', 'tries_remains': 3, 'word': 'i l l a _ a r r a '}
# m 1.24, b 1.15, p 0.97, c 0.88, w 0.7, s 0.58, d 0.58, g 0.51, v 0.46, h 0.4, z 0.26, f 0.19, y 0.18, u 0.17, k 0.12, o 0.12, j 0.09, x 0.05, q 0.01,
# contributions: [0.45427688768445734, 0.9123209132663077, 1.5774841457908109, 2.531779105399881, 3.1849996968593817, 0]
# Guessing letter: m
# Sever response: {'game_id': '48dc45a2be32', 'status': 'ongoing', 'tries_remains': 2, 'word': 'i l l a _ a r r a '}
# b 1.15, p 0.97, c 0.88, w 0.7, s 0.58, d 0.58, g 0.51, v 0.46, h 0.4, z 0.26, f 0.19, y 0.18, u 0.17, k 0.12, o 0.12, j 0.09, x 0.05, q 0.01,
# contributions: [0.4250070361351427, 0.7978265855816162, 1.3738283608816708, 2.1436725880761807, 2.679057780530549, 0]
# Guessing letter: b
# Sever response: {'game_id': '48dc45a2be32', 'status': 'ongoing', 'tries_remains': 1, 'word': 'i l l a _ a r r a '}
# p 0.97, c 0.88, w 0.7, s 0.58, d 0.58, g 0.51, v 0.46, h 0.4, z 0.26, f 0.19, y 0.18, u 0.17, k 0.12, o 0.12, j 0.09, x 0.05, q 0.01,
# contributions: [0.4062565596075954, 0.7219226547797459, 1.2350134830312944, 1.7452287116019862, 2.1595832392825955, 0]
# Guessing letter: p
# Sever response: {'game_id': '48dc45a2be32', 'status': 'failed', 'tries_remains': 0, 'word': 'i l l a _ a r r a '}
# Failed game: 48dc45a2be32. Because of: # of tries exceeded!
# practice success rate so far =  0.75
# Successfully start a new game! Game ID: d97b6edbd86d. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ .
# e 1.32, i 1.04, a 1.02, n 0.86, o 0.85, r 0.84, s 0.84, t 0.78, l 0.69, c 0.5, u 0.44, d 0.42, p 0.37, m 0.35, h 0.33, g 0.29, y 0.23, b 0.23, f 0.15, v 0.12, k 0.11, w 0.1, z 0.05, x 0.03, q 0.02, j 0.02,
# contributions: [11.99999999999999, 0, 0, 0, 0, 0]
# Guessing letter: e
# Sever response: {'game_id': 'd97b6edbd86d', 'status': 'ongoing', 'tries_remains': 6, 'word': 'e _ _ _ _ _ _ e _ _ _ _ '}
# r 1.2, n 1.04, s 1.03, a 0.96, i 0.93, t 0.87, l 0.82, o 0.74, d 0.65, c 0.54, m 0.42, p 0.41, u 0.4, h 0.34, g 0.3, b 0.24, y 0.21, v 0.17, f 0.16, k 0.12, w 0.11, x 0.06, z 0.06, q 0.02, j 0.02,
# contributions: [8.899892034153735, 2.921699397651826, 0, 0, 0, 0]
# Guessing letter: r
# Sever response: {'game_id': 'd97b6edbd86d', 'status': 'ongoing', 'tries_remains': 5, 'word': 'e _ _ _ _ _ _ e _ _ _ _ '}
# n 1.04, s 1.03, a 0.96, i 0.93, t 0.87, l 0.82, o 0.74, d 0.65, c 0.54, m 0.42, p 0.41, u 0.4, h 0.34, g 0.3, b 0.24, y 0.21, v 0.17, f 0.16, k 0.12, w 0.11, x 0.06, z 0.06, q 0.02, j 0.02,
# contributions: [8.197558672895493, 2.419877332484154, 0, 0, 0, 0]
# Guessing letter: n
# Sever response: {'game_id': 'd97b6edbd86d', 'status': 'ongoing', 'tries_remains': 4, 'word': 'e _ _ _ _ _ _ e _ _ _ _ '}
# s 1.03, a 0.96, i 0.93, t 0.87, l 0.82, o 0.74, d 0.65, c 0.54, m 0.42, p 0.41, u 0.4, h 0.34, g 0.3, b 0.24, y 0.21, v 0.17, f 0.16, k 0.12, w 0.11, x 0.06, z 0.06, q 0.02, j 0.02,
# contributions: [7.480960077110392, 2.10113231446018, 0, 0, 0, 0]
# Guessing letter: s
# Sever response: {'game_id': 'd97b6edbd86d', 'status': 'ongoing', 'tries_remains': 4, 'word': 'e _ _ s _ _ _ e _ _ _ _ '}
# i 1.12, t 1.02, a 1.02, o 0.8, l 0.8, d 0.63, c 0.55, u 0.51, p 0.44, m 0.43, h 0.38, g 0.29, b 0.23, y 0.23, v 0.16, f 0.16, k 0.13, w 0.12, x 0.06, z 0.06, q 0.03, j 0.02,
# contributions: [6.104008667388945, 3.069742459830861, 0, 0, 0, 0]
# Guessing letter: i
# Sever response: {'game_id': 'd97b6edbd86d', 'status': 'ongoing', 'tries_remains': 4, 'word': 'e _ i s _ _ _ e _ i _ _ '}
# t 1.84, l 1.34, m 1.1, d 1.04, a 0.94, c 0.83, o 0.76, p 0.65, h 0.6, g 0.42, u 0.41, v 0.37, b 0.3, f 0.3, w 0.22, y 0.21, k 0.18, x 0.15, z 0.09, q 0.03, j 0.03,
# contributions: [4.138914486719823, 4.403647602446639, 2.6838357392728347, 0.5785547785547787, 0, 0]
# Guessing letter: t
# Sever response: {'game_id': 'd97b6edbd86d', 'status': 'ongoing', 'tries_remains': 4, 'word': 'e _ i s t _ _ e _ i _ _ '}
# l 1.53, d 1.14, m 1.12, a 1.09, o 0.94, c 0.73, p 0.67, h 0.58, g 0.56, u 0.41, v 0.39, f 0.31, b 0.28, x 0.24, y 0.24, w 0.23, k 0.16, z 0.09, j 0.02, q 0.02,
# contributions: [3.159989005744687, 3.562743634544591, 2.0423682968593653, 1.397200797016511, 0.5868263473053892, 0]
# Guessing letter: l
# Sever response: {'game_id': 'd97b6edbd86d', 'status': 'ongoing', 'tries_remains': 4, 'word': 'e _ i s t _ _ e _ i _ l '}
# a 1.44, d 1.13, m 1.1, o 1.03, c 0.74, p 0.72, g 0.58, h 0.56, u 0.44, b 0.42, v 0.38, f 0.34, y 0.24, x 0.24, w 0.23, k 0.16, z 0.09, j 0.02, q 0.02,
# contributions: [2.3452167929719616, 3.6346079510431353, 2.2087876848900976, 1.1627779019143831, 0.5129740518962076, 0]
# Guessing letter: a
# Sever response: {'game_id': 'd97b6edbd86d', 'status': 'ongoing', 'tries_remains': 4, 'word': 'e _ i s t a _ e _ i a l '}
# d 1.82, m 1.66, c 1.32, g 1.0, p 0.85, v 0.58, b 0.57, h 0.55, k 0.41, o 0.34, x 0.33, f 0.33, u 0.28, w 0.24, y 0.18, z 0.09, j 0.02, q 0.01,
# contributions: [1.1532121957165709, 2.344109209276356, 2.5349665573961397, 2.5417371262555974, 1.9964557945638348, 0]
# Guessing letter: d
# Sever response: {'game_id': 'd97b6edbd86d', 'status': 'ongoing', 'tries_remains': 4, 'word': 'e _ i s t a _ e d i a l '}
# m 2.19, p 1.24, g 1.17, c 0.97, h 0.59, v 0.58, b 0.53, k 0.48, x 0.3, o 0.26, f 0.26, w 0.22, u 0.22, y 0.21, z 0.11, j 0.02, q 0.01,
# contributions: [0.6983470024181714, 1.2938743512948188, 1.79104839462197, 2.3350131195043926, 3.224962929835235, 0]
# Guessing letter: m
# Sever response: {'game_id': 'd97b6edbd86d', 'status': 'ongoing', 'tries_remains': 3, 'word': 'e _ i s t a _ e d i a l '}
# p 1.24, g 1.17, c 0.97, h 0.59, v 0.58, b 0.53, k 0.48, x 0.3, o 0.26, f 0.26, w 0.22, u 0.22, y 0.21, z 0.11, j 0.02, q 0.01,
# contributions: [0.6398072993195422, 1.1080246659029522, 1.4521653309924603, 1.810784278074522, 2.146986191268599, 0]
# Guessing letter: p
# Sever response: {'game_id': 'd97b6edbd86d', 'status': 'success', 'tries_remains': 3, 'word': 'e p i s t a p e d i a l '}
# Successfully finished game: d97b6edbd86d
# practice success rate so far =  0.7777777777777778
# Successfully start a new game! Game ID: 3918e88364d3. # of tries remaining: 6. Word: _ _ _ _ .
# e 0.44, i 0.35, a 0.34, n 0.29, o 0.28, r 0.28, s 0.28, t 0.26, l 0.23, c 0.17, u 0.15, d 0.14, p 0.12, m 0.12, h 0.11, g 0.1, y 0.08, b 0.08, f 0.05, v 0.04, k 0.04, w 0.03, z 0.02, x 0.01, q 0.01, j 0.01,
# contributions: [3.9999999999999964, 0, 0, 0, 0, 0]
# Guessing letter: e
# Sever response: {'game_id': '3918e88364d3', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ e '}
# r 0.32, t 0.31, n 0.3, i 0.3, l 0.27, s 0.27, a 0.27, o 0.22, d 0.17, c 0.17, p 0.14, m 0.14, h 0.13, u 0.12, g 0.11, b 0.08, v 0.08, y 0.06, f 0.05, k 0.05, w 0.04, z 0.03, x 0.01, j 0.01, q 0.01,
# contributions: [2.669967610246118, 0.9759377023299539, 0, 0, 0, 0]
# Guessing letter: r
# Sever response: {'game_id': '3918e88364d3', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ e '}
# t 0.31, n 0.3, i 0.3, l 0.27, s 0.27, a 0.27, o 0.22, d 0.17, c 0.17, p 0.14, m 0.14, h 0.13, u 0.12, g 0.11, b 0.08, v 0.08, y 0.06, f 0.05, k 0.05, w 0.04, z 0.03, x 0.01, j 0.01, q 0.01,
# contributions: [2.459267601868646, 0.8659588998572049, 0, 0, 0, 0]
# Guessing letter: t
# Sever response: {'game_id': '3918e88364d3', 'status': 'ongoing', 'tries_remains': 5, 'word': 't _ t e '}
# a 1.72, i 0.98, s 0.47, o 0.43, n 0.35, u 0.25, h 0.15, c 0.12, l 0.11, y 0.08, p 0.07, d 0.04, m 0.04, f 0.03, g 0.03, b 0.03, w 0.02, x 0.02, k 0.01, v 0.01, z 0.01, j 0.0, q 0.0,
# contributions: [0.7551472034774981, 1.4993374838321187, 1.729415679357763, 0.9742547425474255, 0, 0]
# Guessing letter: a
# Sever response: {'game_id': '3918e88364d3', 'status': 'ongoing', 'tries_remains': 4, 'word': 't _ t e '}
# i 0.98, s 0.47, o 0.43, n 0.35, u 0.25, h 0.15, c 0.12, l 0.11, y 0.08, p 0.07, d 0.04, m 0.04, f 0.03, g 0.03, b 0.03, w 0.02, x 0.02, k 0.01, v 0.01, z 0.01, j 0.0, q 0.0,
# contributions: [0.670507910121963, 1.2108458049248598, 1.0026023233736912, 0.35772357723577236, 0, 0]
# Guessing letter: i
# Sever response: {'game_id': '3918e88364d3', 'status': 'success', 'tries_remains': 4, 'word': 't i t e '}
# Successfully finished game: 3918e88364d3
# practice success rate so far =  0.8
# Successfully start a new game! Game ID: b2a9c8e27024. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ .
# e 1.87, i 1.48, a 1.44, n 1.22, o 1.2, r 1.19, s 1.19, t 1.1, l 0.98, c 0.72, u 0.62, d 0.6, p 0.53, m 0.5, h 0.46, g 0.41, y 0.33, b 0.32, f 0.21, v 0.17, k 0.15, w 0.14, z 0.07, x 0.05, q 0.03, j 0.03,
# contributions: [17.0, 0, 0, 0, 0, 0]
# Guessing letter: e
# Sever response: {'game_id': 'b2a9c8e27024', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ _ _ _ _ _ _ e _ e _ _ '}
# r 1.84, n 1.67, s 1.48, a 1.43, i 1.41, t 1.4, l 1.32, o 1.11, d 0.93, c 0.81, m 0.68, p 0.63, u 0.59, h 0.54, g 0.47, b 0.38, y 0.34, v 0.32, f 0.26, k 0.19, w 0.18, z 0.1, x 0.09, j 0.04, q 0.03,
# contributions: [13.34983805123058, 3.8976370999817807, 0.9995962392570803, 0, 0, 0]
# Guessing letter: r
# Sever response: {'game_id': 'b2a9c8e27024', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ _ _ _ e _ e _ _ '}
# n 1.67, s 1.48, a 1.43, i 1.41, t 1.4, l 1.32, o 1.11, d 0.93, c 0.81, m 0.68, p 0.63, u 0.59, h 0.54, g 0.47, b 0.38, y 0.34, v 0.32, f 0.26, k 0.19, w 0.18, z 0.1, x 0.09, j 0.04, q 0.03,
# contributions: [12.29633800934321, 3.2858362323413592, 0.8251139182096096, 0, 0, 0]
# Guessing letter: n
# Sever response: {'game_id': 'b2a9c8e27024', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ n _ n _ _ _ n _ _ _ _ e n e _ _ '}
# i 2.36, s 2.28, o 2.21, a 1.9, t 1.59, l 1.23, g 1.07, d 1.07, u 0.86, c 0.83, m 0.65, p 0.55, h 0.47, v 0.43, b 0.34, y 0.31, f 0.25, k 0.21, w 0.17, z 0.09, x 0.08, j 0.03, q 0.03,
# contributions: [8.229056084821435, 6.316892050143356, 2.696866011165369, 1.7676085514071629, 0, 0]
# Guessing letter: i
# Sever response: {'game_id': 'b2a9c8e27024', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ n i n _ _ i n _ _ i _ e n e _ _ '}
# s 2.55, g 2.51, t 2.21, a 1.73, o 1.64, v 1.58, l 1.56, d 1.49, c 1.09, m 0.96, u 0.83, p 0.63, h 0.55, k 0.4, b 0.39, f 0.38, z 0.28, y 0.27, w 0.23, x 0.1, j 0.04, q 0.04,
# contributions: [5.289170564387461, 5.686848069469643, 5.522456966598953, 4.026940873034083, 0.9465517241379311, 0]
# Guessing letter: s
# Sever response: {'game_id': 'b2a9c8e27024', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ n i n s _ i n _ _ i _ e n e s s '}
# t 4.08, l 1.92, v 1.86, o 1.75, u 1.69, a 1.64, p 1.64, h 1.43, g 1.37, c 1.17, m 1.05, d 0.98, k 0.85, w 0.34, b 0.33, f 0.32, z 0.26, y 0.22, x 0.05, j 0.03, q 0.03,
# contributions: [2.956367490514159, 4.57665288910905, 5.166529842304995, 4.846665679862607, 5.448681097375908, 0]
# Guessing letter: t
# Sever response: {'game_id': 'b2a9c8e27024', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ n i n s t i n _ t i _ e n e s s '}
# a 3.93, v 2.76, g 2.59, o 1.89, c 1.65, l 1.38, u 1.21, d 0.8, m 0.77, p 0.41, z 0.35, k 0.32, h 0.27, b 0.22, f 0.22, y 0.14, w 0.1, x 0.04, j 0.02, q 0.01,
# contributions: [1.5799945028723432, 2.5838893680339092, 4.324429103962268, 4.897689093438259, 5.6941882543156135, 0]
# Guessing letter: a
# Sever response: {'game_id': 'b2a9c8e27024', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ n i n s t i n _ t i _ e n e s s '}
# v 2.76, g 2.59, o 1.89, c 1.65, l 1.38, u 1.21, d 0.8, m 0.77, p 0.41, z 0.35, k 0.32, h 0.27, b 0.22, f 0.22, y 0.14, w 0.1, x 0.04, j 0.02, q 0.01,
# contributions: [1.326076622805738, 2.0608306167317267, 3.3997132448949636, 3.9030133960463127, 4.458678689057077, 0]
# Guessing letter: v
# Sever response: {'game_id': 'b2a9c8e27024', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ n i n s t i n _ t i v e n e s s '}
# g 2.0, c 1.62, o 1.54, u 1.19, p 0.26, d 0.22, l 0.2, y 0.11, k 0.11, h 0.1, m 0.1, f 0.07, w 0.06, b 0.06, x 0.02, z 0.01, j 0.01, q 0.01,
# contributions: [0.8642303597700619, 1.0394589352231385, 1.4443133764010634, 1.8712038806823672, 2.4626157946892895, 0]
# Guessing letter: g
# Sever response: {'game_id': 'b2a9c8e27024', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ n i n s t i n _ t i v e n e s s '}
# c 1.62, o 1.54, u 1.19, p 0.26, d 0.22, l 0.2, y 0.11, k 0.11, h 0.1, m 0.1, f 0.07, w 0.06, b 0.06, x 0.02, z 0.01, j 0.01, q 0.01,
# contributions: [0.8154245260374652, 0.8843804504456682, 0.9709473185865762, 1.1451502751488942, 1.868329051988319, 0]
# Guessing letter: c
# Sever response: {'game_id': 'b2a9c8e27024', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ n i n s t i n c t i v e n e s s '}
# o 0.95, u 0.86, l 0.06, m 0.06, y 0.05, h 0.04, d 0.04, w 0.04, p 0.04, k 0.02, b 0.02, f 0.01, z 0.0, x 0.0, q 0.0, j 0.0,
# contributions: [0.36565217677783607, 0.33815541514244535, 0.38926392842618945, 0.4163636363636364, 0.7049180327868853, 0]
# Guessing letter: o
# Sever response: {'game_id': 'b2a9c8e27024', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ n i n s t i n c t i v e n e s s '}
# u 0.86, l 0.06, m 0.06, y 0.05, h 0.04, d 0.04, w 0.04, p 0.04, k 0.02, b 0.02, f 0.01, z 0.0, x 0.0, q 0.0, j 0.0,
# contributions: [0.2950310295913018, 0.14839679636403943, 0.1389995933306222, 0.20787878787878789, 0.47540983606557374, 0]
# Guessing letter: u
# Sever response: {'game_id': 'b2a9c8e27024', 'status': 'success', 'tries_remains': 2, 'word': 'u n i n s t i n c t i v e n e s s '}
# Successfully finished game: b2a9c8e27024
# practice success rate so far =  0.8181818181818182
# Successfully start a new game! Game ID: 6fe65730f6d1. # of tries remaining: 6. Word: _ _ _ _ _ _ .
# e 0.66, i 0.52, a 0.51, n 0.43, o 0.42, r 0.42, s 0.42, t 0.39, l 0.35, c 0.25, u 0.22, d 0.21, p 0.19, m 0.18, h 0.16, g 0.15, y 0.12, b 0.11, f 0.07, v 0.06, k 0.05, w 0.05, z 0.02, x 0.02, q 0.01, j 0.01,
# contributions: [6.0, 0, 0, 0, 0, 0]
# Guessing letter: e
# Sever response: {'game_id': '6fe65730f6d1', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ e _ _ '}
# r 0.66, n 0.56, s 0.55, t 0.49, a 0.49, i 0.49, l 0.46, o 0.38, d 0.35, c 0.29, m 0.23, p 0.23, u 0.2, h 0.19, g 0.17, b 0.13, y 0.11, v 0.11, f 0.09, k 0.07, w 0.06, z 0.04, x 0.03, j 0.01, q 0.01,
# contributions: [4.449946017076861, 1.9488185499908894, 0, 0, 0, 0]
# Guessing letter: r
# Sever response: {'game_id': '6fe65730f6d1', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ e r _ '}
# i 0.71, t 0.66, a 0.6, s 0.57, o 0.51, n 0.47, l 0.41, d 0.33, p 0.32, c 0.3, m 0.29, h 0.25, v 0.23, g 0.2, u 0.2, b 0.18, y 0.15, f 0.12, k 0.1, w 0.08, z 0.04, x 0.02, j 0.02, q 0.01,
# contributions: [3.279023469158195, 1.6580917171017882, 1.8306498961758648, 0, 0, 0]
# Guessing letter: i
# Sever response: {'game_id': '6fe65730f6d1', 'status': 'ongoing', 'tries_remains': 6, 'word': 'i _ _ e r _ '}
# t 0.68, s 0.61, n 0.61, a 0.58, o 0.51, l 0.41, c 0.37, d 0.34, p 0.31, m 0.29, v 0.24, h 0.22, g 0.2, b 0.18, u 0.17, y 0.13, f 0.13, k 0.1, w 0.07, z 0.06, x 0.02, j 0.02, q 0.01,
# ...
# contributions: [3.9999999999999964, 0, 0, 0, 0, 0]
# Guessing letter: e
# Sever response: {'game_id': '11a888521037', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ '}
# i 0.35, a 0.34, n 0.29, o 0.28, r 0.28, s 0.28, t 0.26, l 0.23, c 0.17, u 0.15, d 0.14, p 0.12, m 0.12, h 0.11, g 0.1, y 0.08, b 0.08, f 0.05, v 0.04, k 0.04, w 0.03, z 0.02, x 0.01, q 0.01, j 0.01,
# contributions: [3.55995681366149, 0, 0, 0, 0, 0]
# Guessing letter: i
# Sever response: {'game_id': '11a888521037', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ '}
# a 0.34, n 0.29, o 0.28, r 0.28, s 0.28, t 0.26, l 0.23, c 0.17, u 0.15, d 0.14, p 0.12, m 0.12, h 0.11, g 0.1, y 0.08, b 0.08, f 0.05, v 0.04, k 0.04, w 0.03, z 0.02, x 0.01, q 0.01, j 0.01,
# contributions: [3.2121580650110637, 0, 0, 0, 0, 0]
# Guessing letter: a
# Sever response: {'game_id': '11a888521037', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ '}
# n 0.29, o 0.28, r 0.28, s 0.28, t 0.26, l 0.23, c 0.17, u 0.15, d 0.14, p 0.12, m 0.12, h 0.11, g 0.1, y 0.08, b 0.08, f 0.05, v 0.04, k 0.04, w 0.03, z 0.02, x 0.01, q 0.01, j 0.01,
# contributions: [2.8736008915889233, 0, 0, 0, 0, 0]
# Guessing letter: n
# Sever response: {'game_id': '11a888521037', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ _ _ '}
# o 0.28, r 0.28, s 0.28, t 0.26, l 0.23, c 0.17, u 0.15, d 0.14, p 0.12, m 0.12, h 0.11, g 0.1, y 0.08, b 0.08, f 0.05, v 0.04, k 0.04, w 0.03, z 0.02, x 0.01, q 0.01, j 0.01,
# contributions: [2.5869614532748857, 0, 0, 0, 0, 0]
# Guessing letter: o
# Sever response: {'game_id': '11a888521037', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ _ _ _ '}
# r 0.28, s 0.28, t 0.26, l 0.23, c 0.17, u 0.15, d 0.14, p 0.12, m 0.12, h 0.11, g 0.1, y 0.08, b 0.08, f 0.05, v 0.04, k 0.04, w 0.03, z 0.02, x 0.01, q 0.01, j 0.01,
# contributions: [2.3044768645287492, 0, 0, 0, 0, 0]
# Guessing letter: r
# Sever response: {'game_id': '11a888521037', 'status': 'failed', 'tries_remains': 0, 'word': '_ _ _ _ '}
# Failed game: 11a888521037. Because of: # of tries exceeded!
# practice success rate so far =  0.4639175257731959
# Successfully start a new game! Game ID: 431a7888c996. # of tries remaining: 6. Word: _ _ _ _ _ _ _ .
# e 0.77, i 0.61, a 0.59, n 0.5, o 0.49, r 0.49, s 0.49, t 0.45, l 0.4, c 0.29, u 0.25, d 0.25, p 0.22, m 0.2, h 0.19, g 0.17, y 0.14, b 0.13, f 0.09, v 0.07, k 0.06, w 0.06, z 0.03, x 0.02, q 0.01, j 0.01,
# contributions: [7.000000000000001, 0, 0, 0, 0, 0]
# Guessing letter: e
# Sever response: {'game_id': '431a7888c996', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ '}
# i 0.61, a 0.59, n 0.5, o 0.49, r 0.49, s 0.49, t 0.45, l 0.4, c 0.29, u 0.25, d 0.25, p 0.22, m 0.2, h 0.19, g 0.17, y 0.14, b 0.13, f 0.09, v 0.07, k 0.06, w 0.06, z 0.03, x 0.02, q 0.01, j 0.01,
# contributions: [6.229924423907611, 0, 0, 0, 0, 0]
# Guessing letter: i
# Sever response: {'game_id': '431a7888c996', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ _ _ '}
# a 0.59, n 0.5, o 0.49, r 0.49, s 0.49, t 0.45, l 0.4, c 0.29, u 0.25, d 0.25, p 0.22, m 0.2, h 0.19, g 0.17, y 0.14, b 0.13, f 0.09, v 0.07, k 0.06, w 0.06, z 0.03, x 0.02, q 0.01, j 0.01,
# contributions: [5.621276613769365, 0, 0, 0, 0, 0]
# Guessing letter: a
# Sever response: {'game_id': '431a7888c996', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ _ _ _ '}
# n 0.5, o 0.49, r 0.49, s 0.49, t 0.45, l 0.4, c 0.29, u 0.25, d 0.25, p 0.22, m 0.2, h 0.19, g 0.17, y 0.14, b 0.13, f 0.09, v 0.07, k 0.06, w 0.06, z 0.03, x 0.02, q 0.01, j 0.01,
# contributions: [5.028801560280618, 0, 0, 0, 0, 0]
# Guessing letter: n
# Sever response: {'game_id': '431a7888c996', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ _ _ _ _ _ '}
# o 0.49, r 0.49, s 0.49, t 0.45, l 0.4, c 0.29, u 0.25, d 0.25, p 0.22, m 0.2, h 0.19, g 0.17, y 0.14, b 0.13, f 0.09, v 0.07, k 0.06, w 0.06, z 0.03, x 0.02, q 0.01, j 0.01,
# contributions: [4.527182543231046, 0, 0, 0, 0, 0]
# Guessing letter: o
# Sever response: {'game_id': '431a7888c996', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ _ o _ _ _ '}
# r 0.67, t 0.53, s 0.52, l 0.5, c 0.39, u 0.3, p 0.29, m 0.29, d 0.28, h 0.23, g 0.21, b 0.16, y 0.13, f 0.11, v 0.1, w 0.09, k 0.07, z 0.04, x 0.03, j 0.02, q 0.01,
# contributions: [3.456715296793121, 1.5062285203683847, 0, 0, 0, 0]
# Guessing letter: r
# Sever response: {'game_id': '431a7888c996', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ _ _ o _ _ _ '}
# t 0.53, s 0.52, l 0.5, c 0.39, u 0.3, p 0.29, m 0.29, d 0.28, h 0.23, g 0.21, b 0.16, y 0.13, f 0.11, v 0.1, w 0.09, k 0.07, z 0.04, x 0.03, j 0.02, q 0.01,
# contributions: [3.0353152800381795, 1.2555584112861617, 0, 0, 0, 0]
# Guessing letter: t
# Sever response: {'game_id': '431a7888c996', 'status': 'failed', 'tries_remains': 0, 'word': '_ _ _ o _ _ _ '}
# Failed game: 431a7888c996. Because of: # of tries exceeded!
# practice success rate so far =  0.45918367346938777
# Successfully start a new game! Game ID: f3f6ee46270f. # of tries remaining: 6. Word: _ _ _ _ _ _ .
# e 0.66, i 0.52, a 0.51, n 0.43, o 0.42, r 0.42, s 0.42, t 0.39, l 0.35, c 0.25, u 0.22, d 0.21, p 0.19, m 0.18, h 0.16, g 0.15, y 0.12, b 0.11, f 0.07, v 0.06, k 0.05, w 0.05, z 0.02, x 0.02, q 0.01, j 0.01,
# contributions: [6.0, 0, 0, 0, 0, 0]
# Guessing letter: e
# Sever response: {'game_id': 'f3f6ee46270f', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ '}
# i 0.52, a 0.51, n 0.43, o 0.42, r 0.42, s 0.42, t 0.39, l 0.35, c 0.25, u 0.22, d 0.21, p 0.19, m 0.18, h 0.16, g 0.15, y 0.12, b 0.11, f 0.07, v 0.06, k 0.05, w 0.05, z 0.02, x 0.02, q 0.01, j 0.01,
# contributions: [5.339935220492236, 0, 0, 0, 0, 0]
# Guessing letter: i
# Sever response: {'game_id': 'f3f6ee46270f', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ i _ _ _ _ '}
# n 0.64, t 0.56, s 0.52, a 0.51, r 0.5, l 0.45, o 0.44, c 0.36, d 0.28, m 0.23, p 0.21, u 0.2, h 0.19, g 0.17, b 0.14, f 0.11, v 0.1, y 0.1, k 0.07, w 0.06, z 0.05, x 0.02, j 0.01, q 0.01,
# contributions: [4.015197581263829, 1.9337299177962248, 0, 0, 0, 0]
# Guessing letter: n
# Sever response: {'game_id': 'f3f6ee46270f', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ i n _ _ _ '}
# t 0.75, g 0.72, a 0.55, r 0.5, s 0.49, l 0.46, o 0.44, d 0.37, c 0.32, m 0.26, h 0.22, p 0.21, u 0.2, b 0.13, f 0.13, k 0.12, y 0.11, v 0.11, w 0.09, z 0.05, x 0.02, j 0.01, q 0.01,
# contributions: [2.925518626697026, 1.6469823073975776, 1.7215690918006492, 0, 0, 0]
# Guessing letter: t
# Sever response: {'game_id': 'f3f6ee46270f', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ i n _ t _ '}
# a 1.54, s 0.87, g 0.77, o 0.64, r 0.57, c 0.44, l 0.44, d 0.35, u 0.29, h 0.29, m 0.24, p 0.2, y 0.14, f 0.13, k 0.12, b 0.12, v 0.1, w 0.09, z 0.05, x 0.03, j 0.01, q 0.01,
# contributions: [2.0003129785866163, 2.527240923433437, 2.1606389882033596, 0.7485101311084624, 0, 0]
# Guessing letter: a
# Sever response: {'game_id': 'f3f6ee46270f', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ i n _ t _ '}
# s 0.87, g 0.77, o 0.64, r 0.57, c 0.44, l 0.44, d 0.35, u 0.29, h 0.29, m 0.24, p 0.2, y 0.14, f 0.13, k 0.12, b 0.12, v 0.1, w 0.09, z 0.05, x 0.03, j 0.01, q 0.01,
# contributions: [1.746395098520011, 2.132499248677895, 1.733787967202349, 0.28545887961859356, 0, 0]
# Guessing letter: s
# Sever response: {'game_id': 'f3f6ee46270f', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ i n _ t s '}
# g 0.76, c 0.65, o 0.59, u 0.52, r 0.47, l 0.39, d 0.32, h 0.22, m 0.2, p 0.18, f 0.13, k 0.12, b 0.1, v 0.09, y 0.09, w 0.07, z 0.05, x 0.03, j 0.01, q 0.01,
# contributions: [1.0245177541221395, 1.415223717177401, 1.8847399472026927, 0.472850004584212, 0.18181818181818182, 0]
# Guessing letter: g
# Sever response: {'game_id': 'f3f6ee46270f', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ i n _ t s '}
# c 0.65, o 0.59, u 0.52, r 0.47, l 0.39, d 0.32, h 0.22, m 0.2, p 0.18, f 0.13, k 0.12, b 0.1, v 0.09, y 0.09, w 0.07, z 0.05, x 0.03, j 0.01, q 0.01,
# contributions: [0.9757119203895428, 1.2441481245005568, 1.4060196069567044, 0.41257907765655083, 0.18181818181818182, 0]
# Guessing letter: c
# Sever response: {'game_id': 'f3f6ee46270f', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ i n _ t s '}
# o 0.59, u 0.52, r 0.47, l 0.39, d 0.32, h 0.22, m 0.2, p 0.18, f 0.13, k 0.12, b 0.1, v 0.09, y 0.09, w 0.07, z 0.05, x 0.03, j 0.01, q 0.01,
# contributions: [0.8915917479077499, 1.106040114298546, 1.2572776923027884, 0.31929036398643074, 0, 0]
# Guessing letter: o
# Sever response: {'game_id': 'f3f6ee46270f', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ i n o t s '}
# m 0.52, l 0.49, r 0.39, h 0.31, d 0.27, p 0.21, b 0.18, u 0.15, k 0.11, v 0.08, f 0.06, w 0.06, z 0.04, y 0.04, x 0.02, j 0.0, q 0.0,
# contributions: [0.37517472676734065, 0.5830235824313424, 0.6225643780025664, 0.6464912280701754, 0.7297297297297298, 0]
# Guessing letter: m
# Sever response: {'game_id': 'f3f6ee46270f', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ i n o t s '}
# l 0.49, r 0.39, h 0.31, d 0.27, p 0.21, b 0.18, u 0.15, k 0.11, v 0.08, f 0.06, w 0.06, z 0.04, y 0.04, x 0.02, j 0.0, q 0.0,
# contributions: [0.34590487521802604, 0.5243467029155128, 0.546922089935249, 0.47894736842105257, 0.5405405405405406, 0]
# Guessing letter: l
# Sever response: {'game_id': 'f3f6ee46270f', 'status': 'failed', 'tries_remains': 0, 'word': '_ i n o t s '}
# Failed game: f3f6ee46270f. Because of: # of tries exceeded!
# practice success rate so far =  0.45454545454545453
# Successfully start a new game! Game ID: 913fa5936631. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ .
# e 1.65, i 1.3, a 1.27, n 1.07, o 1.06, r 1.05, s 1.05, t 0.97, l 0.86, c 0.63, u 0.55, d 0.53, p 0.46, m 0.44, h 0.41, g 0.37, y 0.29, b 0.28, f 0.19, v 0.15, k 0.13, w 0.13, z 0.06, x 0.04, q 0.03, j 0.03,
# contributions: [14.999999999999972, 0, 0, 0, 0, 0]
# Guessing letter: e
# Sever response: {'game_id': '913fa5936631', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ e _ _ _ _ _ _ _ _ _ '}
# r 1.29, i 1.27, a 1.25, n 1.21, s 1.18, t 1.07, o 1.01, l 0.98, d 0.67, c 0.67, u 0.53, p 0.5, m 0.5, h 0.44, g 0.39, b 0.3, y 0.28, f 0.2, v 0.2, k 0.15, w 0.14, z 0.07, x 0.06, j 0.03, q 0.03,
# contributions: [12.459848847815211, 1.9488185499908894, 0, 0, 0, 0]
# Guessing letter: r
# Sever response: {'game_id': '913fa5936631', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ e r _ _ _ _ _ _ _ _ '}
# i 1.49, a 1.36, t 1.25, s 1.2, o 1.15, n 1.11, l 0.93, c 0.68, d 0.64, p 0.6, m 0.56, u 0.53, h 0.49, g 0.42, b 0.35, y 0.32, v 0.32, f 0.23, k 0.18, w 0.15, z 0.08, x 0.04, j 0.03, q 0.03,
# contributions: [10.656826274764132, 1.6580917171017882, 1.8306498961758648, 0, 0, 0]
# Guessing letter: i
# Sever response: {'game_id': '913fa5936631', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ e r i _ _ _ i _ _ _ '}
# n 1.82, t 1.73, s 1.38, a 1.34, l 1.09, o 1.06, c 1.04, d 0.83, p 0.83, m 0.66, h 0.57, g 0.49, u 0.49, v 0.44, b 0.39, f 0.3, y 0.23, k 0.21, z 0.2, w 0.15, x 0.06, j 0.03, q 0.03,
# contributions: [8.060867981396369, 3.5439546074930224, 1.8565706207719708, 1.8827222684123726, 0, 0]
# Guessing letter: n
# Sever response: {'game_id': '913fa5936631', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ e r i _ _ _ i _ n _ '}
# o 1.86, t 1.8, a 1.73, s 1.38, c 1.06, l 1.05, d 0.88, p 0.81, g 0.66, m 0.65, u 0.57, h 0.55, v 0.44, b 0.38, f 0.31, y 0.23, k 0.21, z 0.2, w 0.15, x 0.05, j 0.03, q 0.03,
# contributions: [6.611463205484327, 4.237424667254766, 2.5526796582814044, 1.6249081669448886, 0, 0]
# Guessing letter: o
# Sever response: {'game_id': '913fa5936631', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ o _ _ _ e r i _ _ _ i o n _ '}
# t 3.09, s 1.82, a 1.59, l 1.14, c 1.1, d 0.93, p 0.87, m 0.69, g 0.67, h 0.61, u 0.48, v 0.47, b 0.42, f 0.33, y 0.22, k 0.21, z 0.19, w 0.18, x 0.07, j 0.04, q 0.02,
# contributions: [4.724201386895184, 4.078206259382778, 3.122171753331515, 3.2166873945897816, 0, 0]
# Guessing letter: t
# Sever response: {'game_id': '913fa5936631', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ o _ _ _ e r i _ _ t i o n _ '}
# a 3.68, s 2.16, c 1.34, l 0.95, p 0.91, d 0.78, m 0.6, g 0.6, u 0.57, h 0.51, v 0.41, b 0.34, f 0.3, y 0.21, k 0.18, z 0.17, w 0.15, x 0.05, j 0.04, q 0.02,
# contributions: [3.681415566848933, 3.3710099921583896, 2.494254197498554, 2.782782716854554, 1.6626068016792503, 0]
# Guessing letter: a
# Sever response: {'game_id': '913fa5936631', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ o _ _ _ e r i _ a t i o n _ '}
# c 3.09, s 2.23, l 1.46, z 1.38, d 1.23, m 1.13, p 1.0, g 0.9, v 0.77, h 0.55, b 0.47, u 0.46, f 0.33, k 0.22, y 0.2, w 0.18, x 0.08, j 0.04, q 0.02,
# contributions: [2.6476632971658756, 3.2530786932861164, 2.94700985899847, 3.5389566699147137, 3.3678464462503643, 0]
# Guessing letter: c
# Sever response: {'game_id': '913fa5936631', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ o _ _ _ e r i _ a t i o n _ '}
# s 2.23, l 1.46, z 1.38, d 1.23, m 1.13, p 1.0, g 0.9, v 0.77, h 0.55, b 0.47, u 0.46, f 0.33, k 0.22, y 0.2, w 0.18, x 0.08, j 0.04, q 0.02,
# contributions: [2.3953027797204927, 2.824896982246447, 2.3356691677706114, 2.7383786658314238, 2.368189550314475, 0]
# Guessing letter: s
# Sever response: {'game_id': '913fa5936631', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ o _ _ _ e r i _ a t i o n s '}
# z 1.37, l 1.34, m 1.07, d 1.07, p 0.92, v 0.73, g 0.68, h 0.51, b 0.43, u 0.4, f 0.27, k 0.2, w 0.16, y 0.15, x 0.08, j 0.03, q 0.02,
# contributions: [1.6467215375390754, 2.1337026105935304, 1.7464135187246352, 2.1325575032149877, 1.7648318731860069, 0]
# Guessing letter: z
# Sever response: {'game_id': '913fa5936631', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ o _ _ _ e r i z a t i o n s '}
# p 0.66, l 0.62, m 0.61, d 0.46, h 0.42, v 0.38, b 0.29, g 0.28, u 0.26, f 0.14, k 0.12, w 0.11, y 0.1, x 0.03, j 0.02, q 0.01,
# contributions: [1.3009065554188597, 1.3505250554430328, 0.6094619666048235, 0.6368184092046022, 0.6234567901234569, 0]
# Guessing letter: p
# Sever response: {'game_id': '913fa5936631', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ o _ _ _ e r i z a t i o n s '}
# l 0.62, m 0.61, d 0.46, h 0.42, v 0.38, b 0.29, g 0.28, u 0.26, f 0.14, k 0.12, w 0.11, y 0.1, x 0.03, j 0.02, q 0.01,
# contributions: [1.1770611640167814, 1.1987758470572254, 0.49688208616780044, 0.4364682341170585, 0.5555555555555554, 0]
# Guessing letter: l
# Sever response: {'game_id': '913fa5936631', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ o _ _ l e r i z a t i o n s '}
# b 0.5, d 0.37, u 0.32, g 0.26, m 0.21, h 0.19, f 0.15, y 0.12, w 0.11, k 0.1, v 0.07, x 0.02, j 0.01, q 0.01,
# contributions: [0.7099314459234185, 0.842516390234004, 0.3927630002396358, 0.2654241645244216, 0.22012578616352202, 0]
# Guessing letter: b
# Sever response: {'game_id': '913fa5936631', 'status': 'ongoing', 'tries_remains': 4, 'word': 'b o _ _ l e r i z a t i o n s '}
# u 0.38, d 0.34, g 0.23, m 0.16, y 0.12, w 0.12, h 0.11, f 0.11, k 0.09, v 0.06, x 0.05, j 0.01, q 0.01,
# contributions: [0.43578667756051775, 0.48128820212855944, 0.49021822209303223, 0.2056555269922879, 0.15723270440251572, 0]
# Guessing letter: u
# Sever response: {'game_id': '913fa5936631', 'status': 'ongoing', 'tries_remains': 3, 'word': 'b o _ _ l e r i z a t i o n s '}
# d 0.34, g 0.23, m 0.16, y 0.12, w 0.12, h 0.11, f 0.11, k 0.09, v 0.06, x 0.05, j 0.01, q 0.01,
# contributions: [0.3630212740722891, 0.33228276653057237, 0.36557495062378836, 0.18316195372750643, 0.1509433962264151, 0]
# Guessing letter: d
# Sever response: {'game_id': '913fa5936631', 'status': 'ongoing', 'tries_remains': 3, 'word': 'b o _ d l e r i z a t i o n s '}
# w 0.8, m 0.12, g 0.09, y 0.08, v 0.04, h 0.04, x 0.04, f 0.03, k 0.03, j 0.0, q 0.0,
# contributions: [0.14628007300637344, 0.21752518180270294, 0.2053561617670029, 0.12804939643295432, 0.590392131318395, 0]
# Guessing letter: w
# Sever response: {'game_id': '913fa5936631', 'status': 'success', 'tries_remains': 3, 'word': 'b o w d l e r i z a t i o n s '}
# Successfully finished game: 913fa5936631
# practice success rate so far =  0.46
# 46

# %% [markdown]
# ## Playing recorded games:
# Please finalize your code prior to running the cell below. Once this code executes once successfully your submission will be finalized. Our system will not allow you to rerun any additional games.
#
# Please note that it is expected that after you successfully run this block of code that subsequent runs will result in the error message "Your account has been deactivated".
#
# Once you've run this section of the code your submission is complete. Please send us your source code via email.

# %%
[total_practice_runs_,total_recorded_runs_,total_recorded_successes_,total_practice_successes_] = api.my_status()

for i in range(8):
    print('Playing ', i, ' th game')
    # Uncomment the following line to execute your final runs. Do not do this until you are satisfied with your submission
    api.start_game(practice=0,verbose=True)
    [total_practice_runs,total_recorded_runs,total_recorded_successes,total_practice_successes] = api.my_status() # Get my game stats: (# of tries, # of wins)
    print("Successes so far:", total_recorded_successes-total_recorded_successes_)
    print('practice success rate so far = ' , (total_recorded_successes-total_recorded_successes_)/(total_recorded_runs-total_recorded_runs_))

    # DO NOT REMOVE as otherwise the server may lock you out for too high frequency of requests
    time.sleep(0.5)
# Out:
# Playing  0  th game
# Successfully start a new game! Game ID: e7958e712399. # of tries remaining: 6. Word: _ _ _ _ _ _ .
# e 0.66, i 0.52, a 0.51, n 0.43, o 0.42, r 0.42, s 0.42, t 0.39, l 0.35, c 0.25, u 0.22, d 0.21, p 0.19, m 0.18, h 0.16, g 0.15, y 0.12, b 0.11, f 0.07, v 0.06, k 0.05, w 0.05, z 0.02, x 0.02, q 0.01, j 0.01,
# contributions: [6.0, 0, 0, 0, 0, 0]
# Guessing letter: e
# Sever response: {'game_id': 'e7958e712399', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ e '}
# i 0.47, r 0.46, n 0.45, t 0.44, a 0.44, s 0.41, l 0.39, o 0.36, c 0.25, d 0.24, p 0.2, m 0.2, u 0.19, h 0.19, g 0.15, b 0.12, y 0.1, v 0.1, f 0.08, k 0.07, w 0.06, z 0.04, x 0.02, j 0.01, q 0.01,
# contributions: [4.449946017076861, 0.9759377023299539, 0, 0, 0, 0]
# Guessing letter: i
# Sever response: {'game_id': 'e7958e712399', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ e '}
# r 0.46, n 0.45, t 0.44, a 0.44, s 0.41, l 0.39, o 0.36, c 0.25, d 0.24, p 0.2, m 0.2, u 0.19, h 0.19, g 0.15, b 0.12, y 0.1, v 0.1, f 0.08, k 0.07, w 0.06, z 0.04, x 0.02, j 0.01, q 0.01,
# contributions: [4.015197581263829, 0.9391258459055069, 0, 0, 0, 0]
# Guessing letter: r
# Sever response: {'game_id': 'e7958e712399', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ e '}
# n 0.45, t 0.44, a 0.44, s 0.41, l 0.39, o 0.36, c 0.25, d 0.24, p 0.2, m 0.2, u 0.19, h 0.19, g 0.15, b 0.12, y 0.1, v 0.1, f 0.08, k 0.07, w 0.06, z 0.04, x 0.02, j 0.01, q 0.01,
# contributions: [3.66403090063471, 0.8291470434327576, 0, 0, 0, 0]
# Guessing letter: n
# Sever response: {'game_id': 'e7958e712399', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ _ e '}
# t 0.44, a 0.44, s 0.41, l 0.39, o 0.36, c 0.25, d 0.24, p 0.2, m 0.2, u 0.19, h 0.19, g 0.15, b 0.12, y 0.1, v 0.1, f 0.08, k 0.07, w 0.06, z 0.04, x 0.02, j 0.01, q 0.01,
# contributions: [3.305731602742162, 0.7422992665123415, 0, 0, 0, 0]
# Guessing letter: t
# Sever response: {'game_id': 'e7958e712399', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ _ _ _ e '}
# a 0.44, s 0.41, l 0.39, o 0.36, c 0.25, d 0.24, p 0.2, m 0.2, u 0.19, h 0.19, g 0.15, b 0.12, y 0.1, v 0.1, f 0.08, k 0.07, w 0.06, z 0.04, x 0.02, j 0.01, q 0.01,
# contributions: [2.9826882836819073, 0.626027725301333, 0, 0, 0, 0]
# Guessing letter: a
# Sever response: {'game_id': 'e7958e712399', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ a _ a _ e '}
# l 0.93, c 0.59, s 0.53, m 0.5, d 0.41, p 0.37, g 0.33, b 0.29, h 0.28, o 0.25, v 0.23, u 0.2, k 0.15, y 0.13, w 0.12, f 0.11, z 0.08, x 0.04, j 0.03, q 0.01,
# contributions: [1.5356950901425397, 2.899998238394068, 1.1520883935348825, 0, 0, 0]
# Guessing letter: l
# Sever response: {'game_id': 'e7958e712399', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ a _ a _ e '}
# c 0.59, s 0.53, m 0.5, d 0.41, p 0.37, g 0.33, b 0.29, h 0.28, o 0.25, v 0.23, u 0.2, k 0.15, y 0.13, w 0.12, f 0.11, z 0.08, x 0.04, j 0.03, q 0.01,
# contributions: [1.3628306630533724, 2.337653028405804, 0.952667030818417, 0, 0, 0]
# Guessing letter: c
# Sever response: {'game_id': 'e7958e712399', 'status': 'failed', 'tries_remains': 0, 'word': '_ a _ a _ e '}
# Failed game: e7958e712399. Because of: # of tries exceeded!
# Successes so far: 0
# practice success rate so far =  0.0
# Playing  1  th game
# Successfully start a new game! Game ID: 3e3b7f3dbc4c. # of tries remaining: 6. Word: _ _ _ _ _ _ _ .
# e 0.77, i 0.61, a 0.59, n 0.5, o 0.49, r 0.49, s 0.49, t 0.45, l 0.4, c 0.29, u 0.25, d 0.25, p 0.22, m 0.2, h 0.19, g 0.17, y 0.14, b 0.13, f 0.09, v 0.07, k 0.06, w 0.06, z 0.03, x 0.02, q 0.01, j 0.01,
# contributions: [7.000000000000001, 0, 0, 0, 0, 0]
# Guessing letter: e
# Sever response: {'game_id': '3e3b7f3dbc4c', 'status': 'ongoing', 'tries_remains': 6, 'word': 'e _ _ _ _ _ _ '}
# r 0.62, a 0.56, s 0.55, n 0.55, i 0.54, t 0.44, o 0.44, l 0.42, d 0.33, c 0.29, u 0.23, m 0.21, p 0.21, h 0.17, g 0.16, y 0.12, b 0.12, f 0.09, v 0.07, w 0.06, k 0.06, x 0.03, z 0.03, q 0.01, j 0.01,
# contributions: [5.339935220492236, 0.9728808476609356, 0, 0, 0, 0]
# Guessing letter: r
# Sever response: {'game_id': '3e3b7f3dbc4c', 'status': 'ongoing', 'tries_remains': 6, 'word': 'e _ _ _ _ _ r '}
# a 0.62, o 0.49, s 0.49, i 0.48, n 0.48, t 0.46, l 0.36, d 0.31, c 0.28, u 0.26, p 0.24, m 0.18, g 0.17, h 0.16, b 0.13, y 0.11, f 0.09, v 0.06, w 0.05, k 0.05, x 0.03, z 0.02, q 0.01, j 0.01,
# contributions: [4.098779336447744, 1.46874575856872, 0, 0, 0, 0]
# Guessing letter: a
# Sever response: {'game_id': '3e3b7f3dbc4c', 'status': 'ongoing', 'tries_remains': 6, 'word': 'e _ _ _ _ a r '}
# n 0.52, l 0.5, s 0.48, t 0.46, i 0.45, c 0.39, o 0.33, d 0.31, p 0.3, m 0.3, h 0.26, u 0.2, b 0.17, g 0.17, w 0.11, y 0.1, f 0.09, v 0.09, k 0.06, z 0.03, x 0.03, j 0.02, q 0.01,
# contributions: [2.9404662957360546, 1.537939571776267, 0.8959357587676172, 0, 0, 0]
# Guessing letter: n
# Sever response: {'game_id': '3e3b7f3dbc4c', 'status': 'ongoing', 'tries_remains': 5, 'word': 'e _ _ _ _ a r '}
# l 0.5, s 0.48, t 0.46, i 0.45, c 0.39, o 0.33, d 0.31, p 0.3, m 0.3, h 0.26, u 0.2, b 0.17, g 0.17, w 0.11, y 0.1, f 0.09, v 0.09, k 0.06, z 0.03, x 0.03, j 0.02, q 0.01,
# contributions: [2.653826857422016, 1.3558100640802526, 0.8466622965148038, 0, 0, 0]
# Guessing letter: l
# Sever response: {'game_id': '3e3b7f3dbc4c', 'status': 'ongoing', 'tries_remains': 5, 'word': 'e _ _ _ l a r '}
# u 0.81, o 0.49, i 0.46, s 0.4, c 0.31, p 0.28, t 0.28, d 0.25, b 0.19, g 0.16, m 0.13, y 0.13, f 0.13, h 0.1, k 0.04, v 0.04, w 0.04, x 0.02, z 0.02, q 0.01, j 0.01,
# contributions: [1.817505715977345, 1.069306947250342, 0.6702727067838631, 0.739258387286639, 0, 0]
# Guessing letter: u
# Sever response: {'game_id': '3e3b7f3dbc4c', 'status': 'ongoing', 'tries_remains': 4, 'word': 'e _ _ _ l a r '}
# o 0.49, i 0.46, s 0.4, c 0.31, p 0.28, t 0.28, d 0.25, b 0.19, g 0.16, m 0.13, y 0.13, f 0.13, h 0.1, k 0.04, v 0.04, w 0.04, x 0.02, z 0.02, q 0.01, j 0.01,
# contributions: [1.7083576107450031, 0.9868746700444282, 0.5084516565246788, 0.27839905826957034, 0, 0]
# Guessing letter: o
# Sever response: {'game_id': '3e3b7f3dbc4c', 'status': 'ongoing', 'tries_remains': 4, 'word': 'e _ _ o l a r '}
# p 0.77, s 0.61, i 0.5, c 0.47, t 0.43, h 0.37, d 0.3, m 0.28, b 0.17, v 0.15, g 0.14, f 0.09, y 0.07, k 0.05, w 0.05, z 0.04, x 0.03, j 0.02, q 0.01,
# contributions: [0.9976627794569327, 1.1565427181053525, 0.7828316399202355, 0.763873775843308, 0.8522727272727272, 0]
# Guessing letter: p
# Sever response: {'game_id': '3e3b7f3dbc4c', 'status': 'ongoing', 'tries_remains': 3, 'word': 'e _ _ o l a r '}
# s 0.61, i 0.5, c 0.47, t 0.43, h 0.37, d 0.3, m 0.28, b 0.17, v 0.15, g 0.14, f 0.09, y 0.07, k 0.05, w 0.05, z 0.04, x 0.03, j 0.02, q 0.01,
# contributions: [0.9357400837558935, 1.0805450633654559, 0.6658436995536986, 0.6517954298150163, 0.4488636363636363, 0]
# Guessing letter: s
# Sever response: {'game_id': '3e3b7f3dbc4c', 'status': 'ongoing', 'tries_remains': 3, 'word': 'e s _ o l a r '}
# t 1.9, i 1.47, c 1.07, m 0.84, h 0.74, b 0.26, w 0.19, v 0.17, d 0.16, g 0.11, f 0.1, k 0.07, y 0.06, z 0.03, j 0.02, q 0.02, x 0.01,
# contributions: [0.39799721943234617, 1.0672549268989362, 1.7160241383728894, 1.978956845323319, 2.0715909090909093, 0]
# Guessing letter: t
# Sever response: {'game_id': '3e3b7f3dbc4c', 'status': 'ongoing', 'tries_remains': 2, 'word': 'e s _ o l a r '}
# i 1.47, c 1.07, m 0.84, h 0.74, b 0.26, w 0.19, v 0.17, d 0.16, g 0.11, f 0.1, k 0.07, y 0.06, z 0.03, j 0.02, q 0.02, x 0.01,
# contributions: [0.33338855562029535, 0.7898074988908641, 1.202025775279075, 1.3957466435402983, 1.6079545454545459, 0]
# Guessing letter: i
# Sever response: {'game_id': '3e3b7f3dbc4c', 'status': 'ongoing', 'tries_remains': 1, 'word': 'e s _ o l a r '}
# c 1.07, m 0.84, h 0.74, b 0.26, w 0.19, v 0.17, d 0.16, g 0.11, f 0.1, k 0.07, y 0.06, z 0.03, j 0.02, q 0.02, x 0.01,
# contributions: [0.2464388684576886, 0.6020556060885187, 0.9515967228750541, 1.0614126447784311, 0.993560606060606, 0]
# Guessing letter: c
# Sever response: {'game_id': '3e3b7f3dbc4c', 'status': 'success', 'tries_remains': 1, 'word': 'e s c o l a r '}
# Successfully finished game: 3e3b7f3dbc4c
# Successes so far: 1
# practice success rate so far =  0.5
# Playing  2  th game
# Successfully start a new game! Game ID: b51a02be907a. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ .
# e 1.43, i 1.13, a 1.1, n 0.93, o 0.92, r 0.91, s 0.91, t 0.84, l 0.75, c 0.55, u 0.47, d 0.46, p 0.4, m 0.38, h 0.36, g 0.32, y 0.25, b 0.24, f 0.16, v 0.13, k 0.11, w 0.11, z 0.05, x 0.04, q 0.02, j 0.02,
# contributions: [12.99999999999998, 0, 0, 0, 0, 0]
# Guessing letter: e
# Sever response: {'game_id': 'b51a02be907a', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ e _ _ _ _ _ _ _ _ _ '}
# r 1.15, i 1.09, a 1.08, n 1.06, s 1.04, t 0.95, o 0.87, l 0.86, d 0.6, c 0.58, u 0.46, p 0.44, m 0.44, h 0.38, g 0.34, b 0.26, y 0.25, v 0.18, f 0.18, k 0.13, w 0.12, z 0.07, x 0.05, j 0.03, q 0.03,
# contributions: [10.67987044098446, 1.9488185499908894, 0, 0, 0, 0]
# Guessing letter: r
# Sever response: {'game_id': 'b51a02be907a', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ e _ _ r _ _ _ _ _ _ '}
# a 1.29, i 1.2, o 1.06, n 1.02, s 1.02, t 1.0, l 0.82, d 0.62, c 0.6, u 0.51, p 0.49, m 0.44, h 0.38, g 0.36, b 0.29, y 0.27, f 0.18, v 0.18, k 0.13, w 0.12, z 0.06, x 0.05, j 0.03, q 0.02,
# contributions: [9.01731454018504, 3.1268374756705084, 0, 0, 0, 0]
# Guessing letter: a
# Sever response: {'game_id': 'b51a02be907a', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ e _ _ r a _ _ _ _ _ '}
# t 1.39, n 1.23, i 1.05, s 1.01, l 0.97, o 0.93, c 0.74, d 0.68, p 0.6, u 0.54, g 0.52, m 0.48, b 0.41, h 0.38, y 0.25, f 0.22, v 0.2, k 0.14, w 0.14, z 0.07, x 0.05, j 0.03, q 0.02,
# contributions: [7.351165739340137, 2.9866752492475355, 1.713739824416219, 0, 0, 0]
# Guessing letter: t
# Sever response: {'game_id': 'b51a02be907a', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ e _ _ r a _ _ _ _ t '}
# n 1.29, s 1.1, i 1.08, l 0.93, o 0.92, c 0.75, d 0.64, p 0.59, u 0.55, g 0.5, m 0.45, b 0.39, h 0.37, y 0.24, f 0.21, v 0.19, k 0.13, w 0.13, z 0.07, x 0.06, j 0.02, q 0.02,
# contributions: [6.034571191097663, 3.240274599501701, 1.3628577771543167, 0, 0, 0]
# Guessing letter: n
# Sever response: {'game_id': 'b51a02be907a', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ e _ _ r a _ _ _ _ t '}
# s 1.1, i 1.08, l 0.93, o 0.92, c 0.75, d 0.64, p 0.59, u 0.55, g 0.5, m 0.45, b 0.39, h 0.37, y 0.24, f 0.21, v 0.19, k 0.13, w 0.13, z 0.07, x 0.06, j 0.02, q 0.02,
# contributions: [5.389632454891075, 2.7445841646596714, 1.21051432852517, 0, 0, 0]
# Guessing letter: s
# Sever response: {'game_id': 'b51a02be907a', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ s e _ _ r a _ _ _ s t '}
# i 1.58, o 1.11, l 0.89, u 0.79, d 0.65, c 0.63, p 0.58, m 0.47, g 0.45, b 0.38, y 0.28, h 0.26, f 0.18, v 0.13, w 0.12, k 0.12, x 0.06, z 0.05, q 0.03, j 0.02,
# contributions: [3.7028265966849663, 2.2793818883217054, 2.8036124245816945, 0, 0, 0]
# Guessing letter: i
# Sever response: {'game_id': 'b51a02be907a', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ s e _ _ r a _ _ i s t '}
# l 1.16, o 0.91, d 0.86, c 0.67, u 0.65, m 0.64, p 0.63, g 0.56, b 0.38, h 0.38, f 0.23, y 0.22, v 0.2, w 0.16, k 0.13, x 0.08, z 0.05, q 0.02, j 0.02,
# contributions: [2.6521532456114763, 2.1384193961761433, 2.564677759433797, 0.5967246673490277, 0, 0]
# Guessing letter: l
# Sever response: {'game_id': 'b51a02be907a', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ s e _ _ r a _ _ i s t '}
# o 0.91, d 0.86, c 0.67, u 0.65, m 0.64, p 0.63, g 0.56, b 0.38, h 0.38, f 0.23, y 0.22, v 0.2, w 0.16, k 0.13, x 0.08, z 0.05, q 0.02, j 0.02,
# contributions: [2.3064243914331386, 1.8021080314878046, 2.2291916229022104, 0.4530194472876151, 0, 0]
# Guessing letter: o
# Sever response: {'game_id': 'b51a02be907a', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ s e o _ r a _ _ i s t '}
# g 3.69, u 1.56, c 1.08, p 1.06, d 0.76, m 0.64, b 0.49, h 0.36, f 0.29, y 0.23, w 0.22, v 0.2, k 0.13, x 0.06, z 0.05, j 0.02, q 0.01,
# contributions: [1.568914590261613, 1.6687307232367345, 2.7782709476796197, 2.879349507409628, 1.9574468085106382, 0]
# Guessing letter: g
# Sever response: {'game_id': 'b51a02be907a', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ s e o g r a _ _ i s t '}
# p 1.67, u 1.03, m 0.72, d 0.57, c 0.44, h 0.29, b 0.24, v 0.22, y 0.21, f 0.16, w 0.12, k 0.1, x 0.05, z 0.05, j 0.01, q 0.01,
# contributions: [1.1575200047440966, 0.8895144629045507, 1.0780208637383295, 1.2671876586220527, 1.4880843263061412, 0]
# Guessing letter: p
# Sever response: {'game_id': 'b51a02be907a', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ s e o g r a p _ i s t '}
# h 5.46, u 1.05, d 0.4, m 0.34, y 0.23, c 0.22, f 0.13, b 0.13, w 0.12, v 0.11, k 0.08, x 0.03, z 0.02, j 0.01, q 0.01,
# contributions: [0.7752559600065135, 0.7265506635893417, 1.2213049214577412, 2.115051708338608, 3.5035986339212, 0]
# Guessing letter: h
# Sever response: {'game_id': 'b51a02be907a', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ s e o g r a p h i s t '}
# u 0.87, y 0.11, d 0.09, c 0.09, m 0.07, b 0.06, f 0.03, k 0.03, w 0.02, v 0.02, z 0.01, x 0.01, q 0.0, j 0.0,
# contributions: [0.4621945399591291, 0.16137264878572757, 0.13174233604967017, 0.16666666666666666, 0.5, 0]
# Guessing letter: u
# Sever response: {'game_id': 'b51a02be907a', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ u s e o g r a p h i s t '}
# m 0.66, c 0.2, f 0.15, b 0.13, d 0.09, q 0.06, j 0.03, y 0.03, k 0.02, v 0.02, w 0.01, x 0.01, z 0.01,
# contributions: [0.19471456823545027, 0.3061402168932335, 0.17179007395527046, 0.22441860465116278, 0.5, 0]
# Guessing letter: m
# Sever response: {'game_id': 'b51a02be907a', 'status': 'success', 'tries_remains': 4, 'word': 'm u s e o g r a p h i s t '}
# Successfully finished game: b51a02be907a
# Successes so far: 2
# practice success rate so far =  0.6666666666666666
# Playing  3  th game
# Successfully start a new game! Game ID: 84267a93f482. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ .
# e 0.99, i 0.78, a 0.76, n 0.64, o 0.64, r 0.63, s 0.63, t 0.58, l 0.52, c 0.38, u 0.33, d 0.32, p 0.28, m 0.26, h 0.25, g 0.22, y 0.17, b 0.17, f 0.11, v 0.09, k 0.08, w 0.08, z 0.04, x 0.03, q 0.02, j 0.02,
# contributions: [9.000000000000002, 0, 0, 0, 0, 0]
# Guessing letter: e
# Sever response: {'game_id': '84267a93f482', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ _ e _ '}
# r 0.87, n 0.78, s 0.76, i 0.75, a 0.74, t 0.69, l 0.63, o 0.59, d 0.46, c 0.42, m 0.32, p 0.32, u 0.31, h 0.28, g 0.24, b 0.19, y 0.17, v 0.14, f 0.13, k 0.1, w 0.09, z 0.05, x 0.04, j 0.02, q 0.02,
# contributions: [7.119913627322986, 1.9488185499908894, 0, 0, 0, 0]
# Guessing letter: r
# Sever response: {'game_id': '84267a93f482', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ e _ '}
# n 0.78, s 0.76, i 0.75, a 0.74, t 0.69, l 0.63, o 0.59, d 0.46, c 0.42, m 0.32, p 0.32, u 0.31, h 0.28, g 0.24, b 0.19, y 0.17, v 0.14, f 0.13, k 0.1, w 0.09, z 0.05, x 0.04, j 0.02, q 0.02,
# contributions: [6.558046938316391, 1.6429181161706792, 0, 0, 0, 0]
# Guessing letter: n
# Sever response: {'game_id': '84267a93f482', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ n _ e _ '}
# i 1.04, t 0.96, a 0.93, s 0.81, o 0.8, d 0.69, l 0.6, c 0.56, g 0.46, u 0.4, m 0.32, p 0.31, h 0.27, b 0.19, y 0.17, v 0.16, f 0.15, k 0.12, w 0.1, z 0.05, x 0.04, j 0.02, q 0.02,
# contributions: [5.236672053977272, 3.0657118291801075, 0.8809965380811078, 0, 0, 0]
# Guessing letter: i
# Sever response: {'game_id': '84267a93f482', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ n _ e _ '}
# t 0.96, a 0.93, s 0.81, o 0.8, d 0.69, l 0.6, c 0.56, g 0.46, u 0.4, m 0.32, p 0.31, h 0.27, b 0.19, y 0.17, v 0.16, f 0.15, k 0.12, w 0.1, z 0.05, x 0.04, j 0.02, q 0.02,
# contributions: [4.628024243839026, 2.6571559512721117, 0.8543521266073194, 0, 0, 0]
# Guessing letter: t
# Sever response: {'game_id': '84267a93f482', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ t _ _ n _ e _ '}
# a 1.13, s 0.93, o 0.89, d 0.66, l 0.58, c 0.57, u 0.44, g 0.44, h 0.34, p 0.31, m 0.3, y 0.19, b 0.18, v 0.15, f 0.15, k 0.12, w 0.1, z 0.05, x 0.04, j 0.02, q 0.02,
# contributions: [3.5792259404182887, 3.382540916556708, 0.6423714144411473, 0, 0, 0]
# Guessing letter: a
# Sever response: {'game_id': '84267a93f482', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ t _ a n _ e _ '}
# c 1.05, s 1.02, d 0.97, l 0.77, o 0.73, g 0.7, h 0.67, m 0.57, u 0.39, p 0.37, b 0.24, y 0.2, k 0.2, v 0.19, f 0.18, w 0.16, z 0.07, x 0.05, j 0.04, q 0.02,
# contributions: [2.559491816904235, 3.011825434560147, 2.022270688737349, 0.9990935264238114, 0, 0]
# Guessing letter: c
# Sever response: {'game_id': '84267a93f482', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ t _ a n c e _ '}
# s 1.5, l 1.19, d 0.89, m 0.69, h 0.65, o 0.59, p 0.57, u 0.39, y 0.22, g 0.21, b 0.2, v 0.18, f 0.16, w 0.16, k 0.07, z 0.05, x 0.04, j 0.03, q 0.01,
# contributions: [1.8793531085598008, 1.7042891008140209, 1.3451156616029414, 1.4398714347879054, 1.419996251874063, 0]
# Guessing letter: s
# Sever response: {'game_id': '84267a93f482', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ t _ a n c e _ '}
# l 1.19, d 0.89, m 0.69, h 0.65, o 0.59, p 0.57, u 0.39, y 0.22, g 0.21, b 0.2, v 0.18, f 0.16, w 0.16, k 0.07, z 0.05, x 0.04, j 0.03, q 0.01,
# contributions: [1.5998618187773979, 1.3449604276611056, 1.1957562875292862, 1.1277724807088343, 1.0230697151424286, 0]
# Guessing letter: l
# Sever response: {'game_id': '84267a93f482', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ t _ a n c e _ '}
# d 0.89, m 0.69, h 0.65, o 0.59, p 0.57, u 0.39, y 0.22, g 0.21, b 0.2, v 0.18, f 0.16, w 0.16, k 0.07, z 0.05, x 0.04, j 0.03, q 0.01,
# contributions: [1.3693759159918417, 1.1461699084678887, 0.9966201781588292, 0.8876837798227569, 0.6983552866423931, 0]
# Guessing letter: d
# Sever response: {'game_id': '84267a93f482', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ t d a n c e d '}
# u 1.45, o 0.37, h 0.16, p 0.09, m 0.06, g 0.06, y 0.05, f 0.04, b 0.04, v 0.02, k 0.02, w 0.02, x 0.01, z 0.01, q 0.0, j 0.0,
# contributions: [0.6142268299363782, 0.1709126114160439, 0.44171779141104295, 0.5, 0.6666666666666666, 0]
# Guessing letter: u
# Sever response: {'game_id': '84267a93f482', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ u t d a n c e d '}
# o 2.5, p 0.13, b 0.13, m 0.11, h 0.1, g 0.08, q 0.06, f 0.06, y 0.02, j 0.02, k 0.02, v 0.01, w 0.01, z 0.01, x 0.01,
# contributions: [0.27073071322407477, 0.48539789216435003, 0.5228915662650603, 0.9787234042553192, 1.0, 0]
# Guessing letter: o
# Sever response: {'game_id': '84267a93f482', 'status': 'success', 'tries_remains': 2, 'word': 'o u t d a n c e d '}
# Successfully finished game: 84267a93f482
# Successes so far: 3
# practice success rate so far =  0.75
# Playing  4  th game
# Successfully start a new game! Game ID: 11517d7fd544. # of tries remaining: 6. Word: _ _ _ _ _ .
# e 0.55, i 0.43, a 0.42, n 0.36, o 0.35, r 0.35, s 0.35, t 0.32, l 0.29, c 0.21, u 0.18, d 0.18, p 0.15, m 0.15, h 0.14, g 0.12, y 0.1, b 0.09, f 0.06, v 0.05, k 0.04, w 0.04, z 0.02, x 0.01, q 0.01, j 0.01,
# contributions: [4.999999999999997, 0, 0, 0, 0, 0]
# Guessing letter: e
# Sever response: {'game_id': '11517d7fd544', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ '}
# i 0.43, a 0.42, n 0.36, o 0.35, r 0.35, s 0.35, t 0.32, l 0.29, c 0.21, u 0.18, d 0.18, p 0.15, m 0.15, h 0.14, g 0.12, y 0.1, b 0.09, f 0.06, v 0.05, k 0.04, w 0.04, z 0.02, x 0.01, q 0.01, j 0.01,
# contributions: [4.449946017076861, 0, 0, 0, 0, 0]
# Guessing letter: i
# Sever response: {'game_id': '11517d7fd544', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ '}
# a 0.42, n 0.36, o 0.35, r 0.35, s 0.35, t 0.32, l 0.29, c 0.21, u 0.18, d 0.18, p 0.15, m 0.15, h 0.14, g 0.12, y 0.1, b 0.09, f 0.06, v 0.05, k 0.04, w 0.04, z 0.02, x 0.01, q 0.01, j 0.01,
# contributions: [4.015197581263829, 0, 0, 0, 0, 0]
# Guessing letter: a
# Sever response: {'game_id': '11517d7fd544', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ _ '}
# n 0.36, o 0.35, r 0.35, s 0.35, t 0.32, l 0.29, c 0.21, u 0.18, d 0.18, p 0.15, m 0.15, h 0.14, g 0.12, y 0.1, b 0.09, f 0.06, v 0.05, k 0.04, w 0.04, z 0.02, x 0.01, q 0.01, j 0.01,
# contributions: [3.592001114486153, 0, 0, 0, 0, 0]
# Guessing letter: n
# Sever response: {'game_id': '11517d7fd544', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ _ _ _ '}
# o 0.35, r 0.35, s 0.35, t 0.32, l 0.29, c 0.21, u 0.18, d 0.18, p 0.15, m 0.15, h 0.14, g 0.12, y 0.1, b 0.09, f 0.06, v 0.05, k 0.04, w 0.04, z 0.02, x 0.01, q 0.01, j 0.01,
# contributions: [3.2337018165936064, 0, 0, 0, 0, 0]
# Guessing letter: o
# Sever response: {'game_id': '11517d7fd544', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ o o _ _ '}
# r 0.69, t 0.55, l 0.52, d 0.4, s 0.38, c 0.32, m 0.32, p 0.28, h 0.27, f 0.22, u 0.2, g 0.18, b 0.18, w 0.18, k 0.15, v 0.08, z 0.07, y 0.07, x 0.02, j 0.01, q 0.01,
# contributions: [1.7283576483965608, 1.5062285203683847, 1.8758621928308952, 0, 0, 0]
# Guessing letter: r
# Sever response: {'game_id': '11517d7fd544', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ o o _ _ '}
# t 0.55, l 0.52, d 0.4, s 0.38, c 0.32, m 0.32, p 0.28, h 0.27, f 0.22, u 0.2, g 0.18, b 0.18, w 0.18, k 0.15, v 0.08, z 0.07, y 0.07, x 0.02, j 0.01, q 0.01,
# contributions: [1.51765764001909, 1.2555584112861617, 1.6428418507915186, 0, 0, 0]
# Guessing letter: t
# Sever response: {'game_id': '11517d7fd544', 'status': 'failed', 'tries_remains': 0, 'word': '_ o o _ _ '}
# Failed game: 11517d7fd544. Because of: # of tries exceeded!
# Successes so far: 3
# practice success rate so far =  0.6
# Playing  5  th game
# Successfully start a new game! Game ID: 07475eee50ba. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ .
# e 1.43, i 1.13, a 1.1, n 0.93, o 0.92, r 0.91, s 0.91, t 0.84, l 0.75, c 0.55, u 0.47, d 0.46, p 0.4, m 0.38, h 0.36, g 0.32, y 0.25, b 0.24, f 0.16, v 0.13, k 0.11, w 0.11, z 0.05, x 0.04, q 0.02, j 0.02,
# contributions: [12.99999999999998, 0, 0, 0, 0, 0]
# Guessing letter: e
# Sever response: {'game_id': '07475eee50ba', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ _ _ _ _ '}
# i 1.13, a 1.1, n 0.93, o 0.92, r 0.91, s 0.91, t 0.84, l 0.75, c 0.55, u 0.47, d 0.46, p 0.4, m 0.38, h 0.36, g 0.32, y 0.25, b 0.24, f 0.16, v 0.13, k 0.11, w 0.11, z 0.05, x 0.04, q 0.02, j 0.02,
# contributions: [11.569859644399829, 0, 0, 0, 0, 0]
# Guessing letter: i
# Sever response: {'game_id': '07475eee50ba', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ _ _ _ _ _ _ _ _ '}
# a 1.1, n 0.93, o 0.92, r 0.91, s 0.91, t 0.84, l 0.75, c 0.55, u 0.47, d 0.46, p 0.4, m 0.38, h 0.36, g 0.32, y 0.25, b 0.24, f 0.16, v 0.13, k 0.11, w 0.11, z 0.05, x 0.04, q 0.02, j 0.02,
# contributions: [10.439513711285944, 0, 0, 0, 0, 0]
# Guessing letter: a
# Sever response: {'game_id': '07475eee50ba', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ a _ _ _ _ _ _ _ _ a _ '}
# r 1.26, n 1.22, t 1.14, l 1.1, s 0.96, o 0.81, c 0.75, m 0.55, d 0.53, p 0.5, u 0.48, h 0.43, g 0.38, b 0.36, y 0.25, f 0.19, v 0.17, w 0.15, k 0.14, z 0.07, x 0.05, j 0.03, q 0.02,
# contributions: [7.902402451869546, 3.63373743956973, 0, 0, 0, 0]
# Guessing letter: r
# Sever response: {'game_id': '07475eee50ba', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ r a _ _ _ _ _ _ _ _ a _ '}
# t 1.44, n 1.24, l 1.03, o 0.93, s 0.91, c 0.81, p 0.61, d 0.57, u 0.55, g 0.53, m 0.51, b 0.45, h 0.39, y 0.26, f 0.22, v 0.17, w 0.14, k 0.14, z 0.07, x 0.05, j 0.03, q 0.02,
# contributions: [6.481668867714071, 2.9229198675727828, 1.644635009699477, 0, 0, 0]
# Guessing letter: t
# Sever response: {'game_id': '07475eee50ba', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ r a _ _ _ t _ _ _ _ a _ '}
# n 1.31, s 1.03, o 1.02, l 1.01, c 0.82, p 0.6, u 0.6, d 0.53, g 0.51, m 0.48, h 0.46, b 0.43, y 0.28, f 0.22, v 0.16, w 0.15, k 0.13, z 0.07, x 0.05, j 0.03, q 0.02,
# contributions: [5.252024006634204, 3.3594708001933054, 1.2937529624375748, 0, 0, 0]
# Guessing letter: n
# Sever response: {'game_id': '07475eee50ba', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ r a _ _ _ t _ _ _ _ a n '}
# o 0.96, s 0.93, l 0.9, c 0.77, p 0.58, u 0.55, m 0.54, g 0.49, d 0.49, h 0.49, b 0.4, y 0.26, f 0.21, v 0.16, w 0.14, k 0.12, z 0.06, x 0.05, j 0.03, q 0.02,
# contributions: [4.09518690704677, 2.3025575534152676, 1.7473306258221475, 0, 0, 0]
# Guessing letter: o
# Sever response: {'game_id': '07475eee50ba', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ r a _ _ _ t _ _ o _ a n '}
# m 1.19, l 1.14, s 1.03, c 0.95, p 0.73, u 0.61, g 0.59, d 0.57, h 0.55, b 0.48, y 0.3, f 0.25, v 0.23, w 0.21, k 0.15, x 0.08, z 0.08, j 0.04, q 0.02,
# contributions: [3.0889405133601873, 3.113102750602713, 2.2570053436673962, 0.7317829457364341, 0, 0]
# Guessing letter: m
# Sever response: {'game_id': '07475eee50ba', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ r a _ _ _ t _ _ o m a n '}
# c 0.95, s 0.9, l 0.84, p 0.53, d 0.51, h 0.51, w 0.5, g 0.46, u 0.45, b 0.35, y 0.23, f 0.18, v 0.11, k 0.11, z 0.06, x 0.04, j 0.02, q 0.01,
# contributions: [2.4720441878699844, 1.8720895676287272, 1.5197187768842, 0.3973139339675434, 0.5078125, 0]
# Guessing letter: c
# Sever response: {'game_id': '07475eee50ba', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ r a _ _ _ t _ _ o m a n '}
# s 0.9, l 0.84, p 0.53, d 0.51, h 0.51, w 0.5, g 0.46, u 0.45, b 0.35, y 0.23, f 0.18, v 0.11, k 0.11, z 0.06, x 0.04, j 0.02, q 0.01,
# contributions: [2.2196836704246046, 1.6208632773257206, 1.1773560300970036, 0.3424734191382205, 0.455078125, 0]
# Guessing letter: s
# Sever response: {'game_id': '07475eee50ba', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ r a _ _ _ t s _ o m a n '}
# w 1.78, h 0.93, l 0.89, p 0.89, u 0.59, d 0.51, g 0.44, b 0.4, f 0.25, y 0.22, k 0.16, v 0.13, z 0.05, x 0.04, j 0.02, q 0.02,
# contributions: [1.5003722797925028, 1.3876804836734233, 1.9779224202064039, 0.9785669147441127, 1.4761061980694037, 0]
# Guessing letter: w
# Sever response: {'game_id': '07475eee50ba', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ r a _ _ _ t s w o m a n '}
# u 0.79, h 0.49, l 0.49, f 0.49, p 0.37, g 0.33, d 0.29, b 0.26, y 0.13, v 0.08, k 0.06, z 0.03, x 0.03, j 0.01, q 0.01,
# contributions: [1.1669159513654808, 0.7524369957042109, 0.991879952661137, 0.5, 0.47058823529411764, 0]
# Guessing letter: u
# Sever response: {'game_id': '07475eee50ba', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ r a u _ _ t s w o m a n '}
# f 0.65, g 0.56, d 0.55, l 0.52, h 0.47, p 0.31, b 0.27, k 0.1, y 0.09, x 0.07, v 0.04, z 0.02, j 0.01, q 0.01,
# contributions: [0.7660388582917674, 0.5355135042074295, 0.7900686443550748, 1.1628787878787883, 0.4117647058823529, 0]
# Guessing letter: f
# Sever response: {'game_id': '07475eee50ba', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ r a u _ _ t s w o m a n '}
# g 0.56, d 0.55, l 0.52, h 0.47, p 0.31, b 0.27, k 0.1, y 0.09, x 0.07, v 0.04, z 0.02, j 0.01, q 0.01,
# contributions: [0.7287200446547492, 0.5054893416438149, 0.7252588524645559, 0.8850279106858056, 0.17647058823529413, 0]
# Guessing letter: g
# Sever response: {'game_id': '07475eee50ba', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ r a u g _ t s w o m a n '}
# h 7.46, d 0.73, l 0.28, p 0.24, b 0.2, y 0.1, k 0.07, v 0.02, x 0.01, z 0.01, q 0.0, j 0.0,
# contributions: [0.4370075293705694, 0.40777516765118266, 1.144516858679666, 2.6389921302209305, 4.501468308114904, 0]
# Guessing letter: h
# Sever response: {'game_id': '07475eee50ba', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ r a u g h t s w o m a n '}
# d 0.68, p 0.18, b 0.16, l 0.07, k 0.06, y 0.04, v 0.01, z 0.0, x 0.0, j 0.0, q 0.0,
# contributions: [0.1911823813293448, 0.1268377323714487, 0.15004454693150254, 0.28421052631578947, 0.45714285714285713, 0]
# Guessing letter: d
# Sever response: {'game_id': '07475eee50ba', 'status': 'success', 'tries_remains': 2, 'word': 'd r a u g h t s w o m a n '}
# Successfully finished game: 07475eee50ba
# Successes so far: 4
# practice success rate so far =  0.6666666666666666
# Playing  6  th game
# Successfully start a new game! Game ID: 7ce835c61a7d. # of tries remaining: 6. Word: _ _ _ _ _ _ _ .
# e 0.77, i 0.61, a 0.59, n 0.5, o 0.49, r 0.49, s 0.49, t 0.45, l 0.4, c 0.29, u 0.25, d 0.25, p 0.22, m 0.2, h 0.19, g 0.17, y 0.14, b 0.13, f 0.09, v 0.07, k 0.06, w 0.06, z 0.03, x 0.02, q 0.01, j 0.01,
# contributions: [7.000000000000001, 0, 0, 0, 0, 0]
# Guessing letter: e
# Sever response: {'game_id': '7ce835c61a7d', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ '}
# i 0.61, a 0.59, n 0.5, o 0.49, r 0.49, s 0.49, t 0.45, l 0.4, c 0.29, u 0.25, d 0.25, p 0.22, m 0.2, h 0.19, g 0.17, y 0.14, b 0.13, f 0.09, v 0.07, k 0.06, w 0.06, z 0.03, x 0.02, q 0.01, j 0.01,
# contributions: [6.229924423907611, 0, 0, 0, 0, 0]
# Guessing letter: i
# Sever response: {'game_id': '7ce835c61a7d', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ _ _ '}
# a 0.59, n 0.5, o 0.49, r 0.49, s 0.49, t 0.45, l 0.4, c 0.29, u 0.25, d 0.25, p 0.22, m 0.2, h 0.19, g 0.17, y 0.14, b 0.13, f 0.09, v 0.07, k 0.06, w 0.06, z 0.03, x 0.02, q 0.01, j 0.01,
# contributions: [5.621276613769365, 0, 0, 0, 0, 0]
# Guessing letter: a
# Sever response: {'game_id': '7ce835c61a7d', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ a _ '}
# r 0.66, n 0.65, t 0.6, l 0.58, s 0.52, o 0.44, c 0.39, m 0.29, d 0.28, p 0.27, u 0.26, h 0.23, g 0.2, b 0.19, y 0.14, f 0.1, v 0.09, w 0.08, k 0.08, z 0.04, x 0.03, j 0.02, q 0.01,
# contributions: [4.310401337383384, 1.8168687197848634, 0, 0, 0, 0]
# Guessing letter: r
# Sever response: {'game_id': '7ce835c61a7d', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ _ a _ '}
# n 0.65, t 0.6, l 0.58, s 0.52, o 0.44, c 0.39, m 0.29, d 0.28, p 0.27, u 0.26, h 0.23, g 0.2, b 0.19, y 0.14, f 0.1, v 0.09, w 0.08, k 0.08, z 0.04, x 0.03, j 0.02, q 0.01,
# contributions: [3.8890013206284397, 1.5748967884896714, 0, 0, 0, 0]
# Guessing letter: n
# Sever response: {'game_id': '7ce835c61a7d', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ _ a n '}
# l 0.47, t 0.46, s 0.42, o 0.38, m 0.35, c 0.34, h 0.26, p 0.24, d 0.23, u 0.21, g 0.18, b 0.16, y 0.12, f 0.09, v 0.09, w 0.07, k 0.06, z 0.03, x 0.02, j 0.02, q 0.01,
# contributions: [2.8825351359644866, 0.6746531085237925, 0.6725336221680658, 0, 0, 0]
# Guessing letter: l
# Sever response: {'game_id': '7ce835c61a7d', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ _ _ _ a n '}
# t 0.46, s 0.42, o 0.38, m 0.35, c 0.34, h 0.26, p 0.24, d 0.23, u 0.21, g 0.18, b 0.16, y 0.12, f 0.09, v 0.09, w 0.07, k 0.06, z 0.03, x 0.02, j 0.02, q 0.01,
# contributions: [2.5944277574825425, 0.5822255659169644, 0.5814152901886451, 0, 0, 0]
# Guessing letter: t
# Sever response: {'game_id': '7ce835c61a7d', 'status': 'ongoing', 'tries_remains': 2, 'word': 't _ _ _ _ a n '}
# o 0.41, s 0.38, m 0.33, h 0.31, c 0.31, p 0.21, u 0.21, d 0.2, g 0.16, b 0.14, y 0.13, f 0.08, v 0.08, w 0.08, k 0.05, z 0.03, x 0.02, j 0.02, q 0.01,
# contributions: [1.817107550737831, 0.8280805291664559, 0.5148027800342991, 0, 0, 0]
# Guessing letter: o
# Sever response: {'game_id': '7ce835c61a7d', 'status': 'ongoing', 'tries_remains': 2, 'word': 't o _ _ _ a n '}
# m 0.48, s 0.39, c 0.35, p 0.31, u 0.26, h 0.21, d 0.21, g 0.2, b 0.15, w 0.11, v 0.1, y 0.09, f 0.08, k 0.06, x 0.04, z 0.03, j 0.02, q 0.01,
# contributions: [1.1509672214937696, 0.9763146893298547, 0.9719714279880977, 0, 0, 0]
# Guessing letter: m
# Sever response: {'game_id': '7ce835c61a7d', 'status': 'ongoing', 'tries_remains': 2, 'word': 't o _ _ m a n '}
# s 0.49, u 0.39, p 0.21, g 0.18, c 0.18, d 0.17, h 0.14, y 0.13, w 0.09, b 0.08, k 0.06, f 0.06, v 0.05, x 0.03, z 0.02, q 0.01, j 0.01,
# contributions: [0.7087717778972167, 0.6763124040017959, 0.5831035396733503, 0.3163090128755365, 0, 0]
# Guessing letter: s
# Sever response: {'game_id': '7ce835c61a7d', 'status': 'ongoing', 'tries_remains': 2, 'word': 't o _ s m a n '}
# u 1.51, p 0.6, d 0.37, w 0.32, b 0.21, g 0.16, c 0.14, k 0.12, y 0.1, h 0.07, f 0.05, v 0.04, x 0.03, z 0.01, q 0.0, j 0.0,
# contributions: [0.2845130665030079, 0.5406376183097108, 0.8896463691342418, 0.8219738366091378, 1.205799151343706, 0]
# Guessing letter: u
# Sever response: {'game_id': '7ce835c61a7d', 'status': 'ongoing', 'tries_remains': 1, 'word': 't o _ s m a n '}
# p 0.6, d 0.37, w 0.32, b 0.21, g 0.16, c 0.14, k 0.12, y 0.1, h 0.07, f 0.05, v 0.04, x 0.03, z 0.01, q 0.0, j 0.0,
# contributions: [0.2481303647588935, 0.36949243624889094, 0.400961029900897, 0.3801714536297699, 0.8381895332390382, 0]
# Guessing letter: p
# Sever response: {'game_id': '7ce835c61a7d', 'status': 'success', 'tries_remains': 1, 'word': 't o p s m a n '}
# Successfully finished game: 7ce835c61a7d
# Successes so far: 5
# practice success rate so far =  0.7142857142857143
# Playing  7  th game
# Successfully start a new game! Game ID: 5c466be0467f. # of tries remaining: 6. Word: _ _ _ _ _ .
# e 0.55, i 0.43, a 0.42, n 0.36, o 0.35, r 0.35, s 0.35, t 0.32, l 0.29, c 0.21, u 0.18, d 0.18, p 0.15, m 0.15, h 0.14, g 0.12, y 0.1, b 0.09, f 0.06, v 0.05, k 0.04, w 0.04, z 0.02, x 0.01, q 0.01, j 0.01,
# contributions: [4.999999999999997, 0, 0, 0, 0, 0]
# Guessing letter: e
# Sever response: {'game_id': '5c466be0467f', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ e _ '}
# r 1.0, n 0.81, s 0.65, l 0.63, t 0.63, d 0.51, a 0.41, i 0.36, m 0.33, c 0.31, o 0.26, p 0.26, h 0.21, v 0.2, g 0.18, u 0.16, b 0.15, f 0.11, y 0.11, k 0.08, w 0.08, x 0.06, z 0.05, j 0.02, q 0.01,
# contributions: [2.669967610246118, 3.8976370999817807, 0.9995962392570803, 0, 0, 0]
# Guessing letter: r
# Sever response: {'game_id': '5c466be0467f', 'status': 'ongoing', 'tries_remains': 6, 'word': 'r e _ e r '}
# t 1.19, n 0.77, v 0.74, s 0.74, d 0.66, l 0.53, p 0.47, m 0.42, f 0.35, c 0.34, a 0.28, h 0.25, g 0.21, i 0.21, b 0.2, o 0.12, w 0.11, y 0.09, x 0.09, k 0.08, u 0.08, z 0.05, j 0.02, q 0.01,
# contributions: [0.819755867289549, 1.6429181161706794, 2.69539252543546, 1.8481591468306335, 0.9999999999999999, 0]
# Guessing letter: t
# Sever response: {'game_id': '5c466be0467f', 'status': 'ongoing', 'tries_remains': 5, 'word': 'r e _ e r '}
# n 0.77, v 0.74, s 0.74, d 0.66, l 0.53, p 0.47, m 0.42, f 0.35, c 0.34, a 0.28, h 0.25, g 0.21, i 0.21, b 0.2, o 0.12, w 0.11, y 0.09, x 0.09, k 0.08, u 0.08, z 0.05, j 0.02, q 0.01,
# contributions: [0.7551472034774981, 1.4727381383343208, 2.334742557400156, 1.4491249572631992, 0.8051282051282052, 0]
# Guessing letter: n
# Sever response: {'game_id': '5c466be0467f', 'status': 'ongoing', 'tries_remains': 4, 'word': 'r e _ e r '}
# v 0.74, s 0.74, d 0.66, l 0.53, p 0.47, m 0.42, f 0.35, c 0.34, a 0.28, h 0.25, g 0.21, i 0.21, b 0.2, o 0.12, w 0.11, y 0.09, x 0.09, k 0.08, u 0.08, z 0.05, j 0.02, q 0.01,
# contributions: [0.6834873438989885, 1.2699417408621259, 2.0470374662474953, 1.2591392005358588, 0.7897435897435897, 0]
# Guessing letter: v
# Sever response: {'game_id': '5c466be0467f', 'status': 'ongoing', 'tries_remains': 3, 'word': 'r e _ e r '}
# s 0.74, d 0.66, l 0.53, p 0.47, m 0.42, f 0.35, c 0.34, a 0.28, h 0.25, g 0.21, i 0.21, b 0.2, o 0.12, w 0.11, y 0.09, x 0.09, k 0.08, u 0.08, z 0.05, j 0.02, q 0.01,
# contributions: [0.6735769828487735, 1.2111254505727709, 1.8585433767602162, 1.0370419037107033, 0.5282051282051282, 0]
# Guessing letter: s
# Sever response: {'game_id': '5c466be0467f', 'status': 'ongoing', 'tries_remains': 2, 'word': 'r e _ e r '}
# d 0.66, l 0.53, p 0.47, m 0.42, f 0.35, c 0.34, a 0.28, h 0.25, g 0.21, i 0.21, b 0.2, o 0.12, w 0.11, y 0.09, x 0.09, k 0.08, u 0.08, z 0.05, j 0.02, q 0.01,
# contributions: [0.603704160403173, 1.0142841526792061, 1.6366825260017854, 0.8902042873025141, 0.4256410256410257, 0]
# Guessing letter: d
# Sever response: {'game_id': '5c466be0467f', 'status': 'ongoing', 'tries_remains': 1, 'word': 'r e _ e r '}
# l 0.53, p 0.47, m 0.42, f 0.35, c 0.34, a 0.28, h 0.25, g 0.21, i 0.21, b 0.2, o 0.12, w 0.11, y 0.09, x 0.09, k 0.08, u 0.08, z 0.05, j 0.02, q 0.01,
# contributions: [0.5684735963734018, 0.8369595153007452, 1.38252795773281, 0.7322649418836641, 0.39230769230769236, 0]
# Guessing letter: l
# Sever response: {'game_id': '5c466be0467f', 'status': 'failed', 'tries_remains': 0, 'word': 'r e _ e r '}
# Failed game: 5c466be0467f. Because of: # of tries exceeded!
# Successes so far: 5
# practice success rate so far =  0.625

# %% [markdown]
# ## To check your game statistics
# 1. Simply use "my_status" method.
# 2. Returns your total number of games, and number of wins.

# %%
[total_practice_runs,total_recorded_runs,total_recorded_successes,total_practice_successes] = api.my_status() # Get my game stats: (# of tries, # of wins)
success_rate = total_recorded_successes/total_recorded_runs
print('overall success rate = %.3f' % success_rate)
# Out:
# overall success rate = 0.625
